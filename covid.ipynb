# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

sidr_data = genfromtxt('svidr1.csv', delimiter=',') #in the form of [t,S,V,I,D,R]

torch.manual_seed(1234)

# %%
# %%time

PATH = 'svidr_norm_simple' 

class DINN(nn.Module):
    def __init__(self, t, S_data, V_data, I_data, D_data, R_data): #[t,S,V,I,D,R]
        super(DINN, self).__init__()
        self.N = 3e8 #population size
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S = torch.tensor(S_data)
        self.V = torch.tensor(V_data)
        self.I = torch.tensor(I_data)
        self.D = torch.tensor(D_data)
        self.R = torch.tensor(R_data)

        self.losses = []
        self.save = 2 #which file to save to

        self.alpha_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.beta_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.sigma_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.lbda_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.rho_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        
        #find values for normalization
        self.S_max = max(self.S)
        self.V_max = max(self.V)
        self.I_max = max(self.I)
        self.D_max = max(self.D)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.V_min = min(self.V)
        self.I_min = min(self.I)
        self.D_min = min(self.D)
        self.R_min = min(self.R)

        #normalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.V_hat = (self.V - self.V_min) / (self.V_max - self.V_min)
        self.I_hat = (self.I - self.I_min) / (self.I_max - self.I_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)

        #matrices (x5 for S,V,I,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 5)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 5)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 5)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 5)); self.m4[:, 3] = 1
        self.m5 = torch.zeros((len(self.t), 5)); self.m5[:, 4] = 1

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha_tilda, self.beta_tilda, self.sigma_tilda, self.lbda_tilda, self.rho_tilda]))

    #force parameters to be in a range
    @property
    def alpha(self):
        return torch.tanh(self.alpha_tilda) * 3.5e-3

    @property
    def beta(self):
        return torch.tanh(self.beta_tilda) *0.5
    
    @property
    def sigma(self):
        return torch.tanh(self.sigma_tilda) *0.1

    @property
    def lbda(self):
        return torch.tanh(self.lbda_tilda) *0.5
    
    @property
    def rho(self):
        return torch.tanh(self.rho_tilda)*0.01

    #nets
    class Net_sidr(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()
            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
            self.fc5=nn.Linear(20, 20)
            self.fc6=nn.Linear(20, 20)
            self.fc7=nn.Linear(20, 20)
            self.fc8=nn.Linear(20, 20)
            self.out=nn.Linear(20, 5) #outputs S, V, I, D, R

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            sidr=F.relu(self.fc5(sidr))
            sidr=F.relu(self.fc6(sidr))
            sidr=F.relu(self.fc7(sidr))
            sidr=F.relu(self.fc8(sidr))
            sidr=self.out(sidr)
            return sidr
            
    def net_f(self, t_batch):
        sidr_hat = self.net_sidr(t_batch)

        S_hat, V_hat, I_hat, D_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3], sidr_hat[:,4]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #V_t
        sidr_hat.backward(self.m2, retain_graph=True)
        V_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_t
        sidr_hat.backward(self.m3, retain_graph=True)
        I_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #D_t
        sidr_hat.backward(self.m4, retain_graph=True)
        D_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m5, retain_graph=True)
        R_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        V = self.V_min + (self.V_max - self.V_min) * V_hat
        I = self.I_min + (self.I_max - self.I_min) * I_hat
        D = self.D_min + (self.D_max - self.D_min) * D_hat      
        R = self.R_min + (self.R_max - self.R_min) * R_hat

        f1_hat = S_hat_t - (-self.beta/self.N * S * I - self.alpha * S)  / (self.S_max - self.S_min)
        f2_hat = V_hat_t - (self.alpha * S - self.sigma * self.beta/self.N * V * I)  / (self.V_max - self.V_min)
        f3_hat = I_hat_t - (self.beta/self.N * S * I + self.sigma * self.beta/self.N * V * I - self.lbda * I - self.rho * I ) / (self.I_max - self.I_min)
        f4_hat = D_hat_t - (self.lbda * I) / (self.D_max - self.D_min)
        f5_hat = R_hat_t - (self.rho * I ) / (self.R_max - self.R_min)

        return f1_hat, f2_hat, f3_hat, f4_hat, f5_hat, S_hat, V_hat, I_hat, D_hat, R_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
        self.losses = checkpoint['losses']

      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S_pred_list = []
        V_pred_list = []
        I_pred_list = []
        D_pred_list = []
        R_pred_list = []

        f1, f2, f3, f4, f5, S_pred, V_pred, I_pred, D_pred, R_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred)
        V_pred_list.append(self.V_min + (self.V_max - self.V_min) * V_pred) 
        I_pred_list.append(self.I_min + (self.I_max - self.I_min) * I_pred)
        D_pred_list.append(self.D_min + (self.D_max - self.D_min) * D_pred)
        R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

        loss = (torch.mean(torch.square(self.S_hat - S_pred))+ 
                torch.mean(torch.square(self.V_hat - V_pred))+
                torch.mean(torch.square(self.I_hat - I_pred))+
                torch.mean(torch.square(self.D_hat - D_pred))+
                torch.mean(torch.square(self.R_hat - R_pred))+
                torch.mean(torch.square(f1))+
                torch.mean(torch.square(f2))+
                torch.mean(torch.square(f3))+
                torch.mean(torch.square(f4))+
                torch.mean(torch.square(f5))
                ) 

        #loss.backward(retain_graph=True)
        loss.backward()
        self.optimizer.step()
        self.scheduler.step() 
        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)
          print('alpha: (goal 3.5e-4 ', self.alpha)
          print('beta: (goal 0.3 ', self.beta)
          print('sigma: (goal 0.05 ', self.sigma)
          print('lbda: (goal 0.1 ', self.lbda)
          print('rho: (goal 1e-3 ', self.rho)
          print('#################################') 

        #loss + model parameters update
        if epoch % 4000 == 9999:
          #checkpoint save
          print('\nSaving model... Loss is: ', loss)
          torch.save({
              'epoch': epoch,
              'model': self.state_dict(),
              'optimizer_state_dict': self.optimizer.state_dict(),
              'scheduler': self.scheduler.state_dict(),
              #'loss': loss,
              'losses': self.losses,
              }, PATH + str(self.save)+'.pt')
          if self.save % 2 > 0: #its on 3
            self.save = 2 #change to 2
          else: #its on 2
            self.save = 3 #change to 3

      return S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list
# Out:
# Wall time: 0 ns

# %%
# %%time

dinn = DINN(sidr_data[0], sidr_data[1], sidr_data[2], sidr_data[3], 
            sidr_data[4], sidr_data[5]) #in the form of [t,S,V,I,D,R]

learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-6, max_lr=1e-3, step_size_up=1000, mode="exp_range", gamma=0.85, cycle_momentum=False)

dinn.scheduler = scheduler

nepochs = int(5e5)

# S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train

try: 
  S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
except EOFError:
  if dinn.save == 2:
    dinn.save = 3
    S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
  elif dinn.save == 3:
    dinn.save = 2
    S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
# Out:
# starting training...
#
#
# Epoch  0
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1908], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0254], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1755], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  1000
# alpha: (goal 3.5e-4  tensor([9.7298e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1912], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1751], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  2000
# alpha: (goal 3.5e-4  tensor([9.3197e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1916], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1748], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  3000
# alpha: (goal 3.5e-4  tensor([8.9418e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1919], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1745], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  4000
# alpha: (goal 3.5e-4  tensor([8.5793e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1923], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1742], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  5000
# alpha: (goal 3.5e-4  tensor([8.2195e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1926], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1739], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  6000
# alpha: (goal 3.5e-4  tensor([7.8606e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1930], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1736], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  7000
# alpha: (goal 3.5e-4  tensor([7.5072e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1933], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1732], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  8000
# alpha: (goal 3.5e-4  tensor([7.1596e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1937], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1729], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  9000
# alpha: (goal 3.5e-4  tensor([6.8252e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1940], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1726], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  10000
# alpha: (goal 3.5e-4  tensor([6.5017e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1944], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1723], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  11000
# alpha: (goal 3.5e-4  tensor([6.1950e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1947], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1719], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  12000
# alpha: (goal 3.5e-4  tensor([5.9197e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1951], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1716], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  13000
# alpha: (goal 3.5e-4  tensor([5.6937e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1954], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1713], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  14000
# alpha: (goal 3.5e-4  tensor([5.6265e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1956], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1711], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  15000
# alpha: (goal 3.5e-4  tensor([5.9499e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1958], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1709], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  16000
# alpha: (goal 3.5e-4  tensor([6.4704e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1960], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1707], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  17000
# alpha: (goal 3.5e-4  tensor([6.9647e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1961], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1706], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  18000
# alpha: (goal 3.5e-4  tensor([7.4302e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1962], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1706], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  19000
# alpha: (goal 3.5e-4  tensor([7.8661e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1963], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1704], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  20000
# alpha: (goal 3.5e-4  tensor([8.2776e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1964], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1702], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  21000
# alpha: (goal 3.5e-4  tensor([8.6683e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1966], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0254], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1698], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  22000
# alpha: (goal 3.5e-4  tensor([9.0376e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1969], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0254], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1693], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  23000
# alpha: (goal 3.5e-4  tensor([9.3854e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1973], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1688], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  24000
# alpha: (goal 3.5e-4  tensor([9.7271e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1977], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1683], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  25000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1981], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1678], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  26000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1986], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1674], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  27000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1991], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0250], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1669], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  28000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1996], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0249], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1664], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  29000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2002], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0249], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1657], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  30000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2006], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0248], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1653], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  31000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2010], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0247], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1648], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  32000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2014], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0247], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1645], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  33000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2018], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1641], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  34000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2023], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0245], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1636], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  35000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2027], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0245], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1632], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  36000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2031], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0244], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1627], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  37000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2035], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0243], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1623], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  38000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2039], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0243], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1619], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  39000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2043], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0242], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1615], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  40000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2047], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0241], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1611], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  41000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2051], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0241], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1606], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  42000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2055], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0240], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1602], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  43000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2059], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0239], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1597], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  44000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2064], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0239], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1593], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  45000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2068], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0238], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1588], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  46000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2072], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0238], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1584], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  47000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2076], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0237], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1580], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  48000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2080], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0236], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1575], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  49000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2084], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0236], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1570], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  50000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2089], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0235], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1566], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  51000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2093], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0235], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1561], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  52000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2097], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0234], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1556], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  53000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2102], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0234], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1552], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  54000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2106], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0234], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1547], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  55000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2110], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0234], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1543], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  56000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2114], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0234], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1538], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  57000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2118], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0234], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1534], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  58000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2122], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0235], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1530], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  59000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2126], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0235], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1525], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  60000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2130], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0236], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1521], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  61000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2134], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0237], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1517], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  62000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2138], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0237], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1512], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  63000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2143], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0238], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1508], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  64000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2147], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0239], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1503], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  65000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2151], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0240], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1498], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  66000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2155], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0240], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1494], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  67000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2159], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0241], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1489], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  68000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2163], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0242], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1485], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  69000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2167], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0243], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1480], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  70000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2171], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0244], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.1475], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# #################################
#
# Epoch
grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0041], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  492000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1919], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0218], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0041], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  493000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1915], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0217], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0041], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  494000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1911], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0216], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0041], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  495000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1907], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0215], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  496000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1903], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0214], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  497000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1898], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0213], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  498000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1894], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0212], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  499000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1890], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0211], grad_fn=<MulBackward0>)
# lbda: (goal 0.1  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 1e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# #################################
# Wall time: 48min 16s

# %%
plt.plot(dinn.losses, color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss'),
# Out:
# (Text(0, 0.5, 'Loss'),)

# %%
fig = plt.figure(figsize=(12,12))

ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')


# ax.scatter(sidr_data[0], sidr_data[1], 'pink', alpha=0.5, lw=2, label='Susceptible', s=15)
ax.scatter(sidr_data[0], sidr_data[1], color = 'darkgreen', label='Susceptible Data', s=15)
ax.plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

# ax.scatter(sidr_data[0], sidr_data[1], 'pink', alpha=0.5, lw=2, label='Susceptible', s=15)
ax.scatter(sidr_data[0], sidr_data[2], color = 'blue', label='Vaccinated Data', s=15)
ax.plot(sidr_data[0], V_pred_list[0].detach().numpy(), 'lightblue', alpha=0.9, lw=2, label='Vaccinated Prediction', linestyle='dashed')

# ax.scatter(sidr_data[0], sidr_data[3], 'violet', alpha=0.5, lw=2, label='Infected', s=15)
ax.scatter(sidr_data[0], sidr_data[3], color = 'red', label='Infected Data', s=15)
ax.plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'pink', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

# ax.scatter(sidr_data[0], sidr_data[4], 'darkgreen', alpha=0.5, lw=2, label='Dead', s=15)
ax.scatter(sidr_data[0], sidr_data[4], color = 'black', label='Dead Data', s=15)
ax.plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'grey', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

# ax.scatter(sidr_data[0], sidr_data[5], '', alpha=0.5, lw=2, label='Recovered', s=15)
ax.scatter(sidr_data[0], sidr_data[5], color = 'green', label='Recovered Data', s=15)
ax.plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'lightgreen', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')


ax.set_xlabel('Time /days',size = 20)
ax.set_ylabel('Number',size = 20)
#ax.set_ylim([-1,50])
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
plt.xticks(size = 20)
plt.yticks(size = 20)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend(prop={'size':20})
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('covid_missing_I.pdf')
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initial conditions
N = 3e8

S0 = N - 1
V0 = 0
I0 = 1
D0 = 0
R0 = 0
# A grid of time points (in days)
t = np.linspace(0, 500, 100) 

#parameters
alpha = dinn.alpha.detach().numpy().item()
beta = dinn.beta.detach().numpy().item()
sigma = dinn.sigma.detach().numpy().item()
lbda = dinn.lbda.detach().numpy().item()
rho = dinn.rho.detach().numpy().item()

# The SIR model differential equations.
def deriv(y, t, alpha, beta, sigma, lbda, rho):
    S, V, I, D, R = y
    dSdt = - beta/N * S * I - alpha * S
    dVdt = alpha * S - sigma * beta/N * V * I
    dIdt = beta/N * S * I + sigma * beta/N * V * I - lbda * I - rho * I 
    dDdt = rho * I
    dRdt = lbda * I

    return dSdt, dVdt, dIdt, dDdt, dRdt


# Initial conditions vector
y0 = S0, V0, I0, D0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(alpha, beta, sigma, lbda, rho))
S, V, I, D, R = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w', figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, S, 'purple', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
# ax.plot(t, sidr_data[1], 'violet', alpha=0.5, lw=2, label='Susceptible')

ax.plot(t, V, 'blue', alpha=0.5, lw=2, label='Learnable Param Vaccinated', linestyle='dashed')
# ax.plot(t, sidr_data[2], 'dodgerblue', alpha=0.5, lw=2, label='Vaccinated')

ax.plot(t, I, 'red', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
# ax.plot(t, sidr_data[3], 'pink', alpha=0.5, lw=2, label='Infected')

ax.plot(t, D, 'black', alpha=0.5, lw=2, label='Learnable Param Dead', linestyle='dashed')
# ax.plot(t, sidr_data[4], 'grey', alpha=0.5, lw=2, label='Dead')

ax.plot(t, R, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Recovered', linestyle='dashed')
# ax.plot(t, sidr_data[5], 'green', alpha=0.5, lw=2, label='Recovered')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()
