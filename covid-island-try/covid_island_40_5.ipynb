# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

sidr_data = genfromtxt('island_40weeks.csv', delimiter=',') #in the form of [t,S,I,R]

torch.manual_seed(1234)

# %%
# %%time

PATH = 'sir_norm_simple' 

class DINN(nn.Module):
    def __init__(self, t, S_data, I_data, R_data): #[t,S,I,D,R]
        super(DINN, self).__init__()
        self.N = 12111 #population size
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S = torch.tensor(S_data)
        self.I = torch.tensor(I_data)
        self.R = torch.tensor(R_data)

        self.losses = []
        self.save = 2 #which file to save to

        self.alpha_tilda = torch.nn.Parameter(torch.rand(1, dtype=torch.float64, requires_grad=True))
        self.beta_tilda = torch.nn.Parameter(torch.rand(1, dtype=torch.float64, requires_grad=True))
        
        #find values for normalization
        self.S_max = max(self.S)
        self.I_max = max(self.I)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.I_min = min(self.I)
        self.R_min = min(self.R)

        #normalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.I_hat = (self.I - self.I_min) / (self.I_max - self.I_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)

        #matrices (x4 for S,I,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 4)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 4)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 4)); self.m3[:, 2] = 1

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha_tilda, self.beta_tilda]))

    @property
    def alpha(self):
        return self.alpha_tilda

    @property
    def beta(self):
        return self.beta_tilda


    #nets
    class Net_sidr(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()
            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
            self.fc5=nn.Linear(20, 20)
            self.fc6=nn.Linear(20, 20)
            self.fc7=nn.Linear(20, 20)
            self.fc8=nn.Linear(20, 20)
            self.out=nn.Linear(20, 4) #outputs S, I, R

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            sidr=F.relu(self.fc5(sidr))
            sidr=F.relu(self.fc6(sidr))
            sidr=F.relu(self.fc7(sidr))
            sidr=F.relu(self.fc8(sidr))
            sidr=self.out(sidr)
            return sidr
            
    def net_f(self, t_batch):
        sidr_hat = self.net_sidr(t_batch)

        S_hat, I_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_t
        sidr_hat.backward(self.m2, retain_graph=True)
        I_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m3, retain_graph=True)
        R_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        I = self.I_min + (self.I_max - self.I_min) * I_hat   
        R = self.R_min + (self.R_max - self.R_min) * R_hat

        f1_hat = S_hat_t - (-(self.alpha / self.N) * S * I)  / (self.S_max - self.S_min)
        f2_hat = I_hat_t - ((self.alpha / self.N) * S * I - self.beta * I) / (self.I_max - self.I_min)
        f3_hat = R_hat_t - (self.beta * I ) / (self.R_max - self.R_min)

        return f1_hat, f2_hat, f3_hat, S_hat, I_hat, R_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
        self.losses = checkpoint['losses']

      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S_pred_list = []
        I_pred_list = []
        R_pred_list = []

        f1, f2, f3, S_pred, I_pred, R_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred) 
        I_pred_list.append(self.I_min + (self.I_max - self.I_min) * I_pred)
        R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

        train_day = 35

        loss = (torch.mean(torch.square(self.S_hat[:train_day] - S_pred[:train_day]))+ 
                torch.mean(torch.square(self.I_hat[:train_day] - I_pred[:train_day]))+
                torch.mean(torch.square(self.R_hat[:train_day] - R_pred[:train_day]))+
                torch.mean(torch.square(f1[:train_day]))+
                torch.mean(torch.square(f2[:train_day]))+
                torch.mean(torch.square(f3[:train_day]))
                ) 

        #loss.backward(retain_graph=True)
        loss.backward()
        self.optimizer.step()
        self.scheduler.step() 
        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)

          print('alpha: ', self.alpha)
          print('beta:', self.beta)

          print('#################################')                

      return S_pred_list, I_pred_list, R_pred_list
# Out:
# Wall time: 0 ns

# %%
# %%time

dinn = DINN(sidr_data[0], sidr_data[1], sidr_data[2],
            sidr_data[3]) #in the form of [t,S,I,R]

learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-6, max_lr=1e-3, step_size_up=5, mode="exp_range", cycle_momentum=False)

dinn.scheduler = scheduler

nepochs = int(1e5)

# S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train

try: 
  S_pred_list, I_pred_list, R_pred_list = dinn.train(nepochs) #train
except EOFError:
  if dinn.save == 2:
    dinn.save = 3
    S_pred_list, I_pred_list, R_pred_list = dinn.train(nepochs) #train
  elif dinn.save == 3:
    dinn.save = 2
    S_pred_list, I_pred_list, R_pred_list = dinn.train(nepochs) #train
# Out:
# starting training...
#
#
# Epoch  0
# alpha:  Parameter containing:
# tensor([0.2318], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0788], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  1000
# alpha:  Parameter containing:
# tensor([0.1863], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0511], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  2000
# alpha:  Parameter containing:
# tensor([0.1815], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0488], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  3000
# alpha:  Parameter containing:
# tensor([0.1799], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0487], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  4000
# alpha:  Parameter containing:
# tensor([0.1785], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0483], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  5000
# alpha:  Parameter containing:
# tensor([0.1774], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0482], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  6000
# alpha:  Parameter containing:
# tensor([0.1758], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0475], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  7000
# alpha:  Parameter containing:
# tensor([0.1760], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0470], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  8000
# alpha:  Parameter containing:
# tensor([0.1765], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0467], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  9000
# alpha:  Parameter containing:
# tensor([0.1768], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0460], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  10000
# alpha:  Parameter containing:
# tensor([0.1752], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0479], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  11000
# alpha:  Parameter containing:
# tensor([0.1753], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0477], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  12000
# alpha:  Parameter containing:
# tensor([0.1756], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0476], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  13000
# alpha:  Parameter containing:
# tensor([0.1775], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0464], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  14000
# alpha:  Parameter containing:
# tensor([0.1765], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0472], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  15000
# alpha:  Parameter containing:
# tensor([0.1755], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0479], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  16000
# alpha:  Parameter containing:
# tensor([0.1730], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0467], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  17000
# alpha:  Parameter containing:
# tensor([0.1760], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0464], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  18000
# alpha:  Parameter containing:
# tensor([0.1729], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0476], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  19000
# alpha:  Parameter containing:
# tensor([0.1740], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0468], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  20000
# alpha:  Parameter containing:
# tensor([0.1748], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0460], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  21000
# alpha:  Parameter containing:
# tensor([0.1758], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0464], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  22000
# alpha:  Parameter containing:
# tensor([0.1785], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0450], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  23000
# alpha:  Parameter containing:
# tensor([0.1765], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0469], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  24000
# alpha:  Parameter containing:
# tensor([0.1748], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0474], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  25000
# alpha:  Parameter containing:
# tensor([0.1747], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0472], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  26000
# alpha:  Parameter containing:
# tensor([0.1764], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0460], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  27000
# alpha:  Parameter containing:
# tensor([0.1753], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0472], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  28000
# alpha:  Parameter containing:
# tensor([0.1759], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0466], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  29000
# alpha:  Parameter containing:
# tensor([0.1761], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0474], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  30000
# alpha:  Parameter containing:
# tensor([0.1761], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0471], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  31000
# alpha:  Parameter containing:
# tensor([0.1753], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0461], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  32000
# alpha:  Parameter containing:
# tensor([0.1762], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0465], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  33000
# alpha:  Parameter containing:
# tensor([0.1759], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0481], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  34000
# alpha:  Parameter containing:
# tensor([0.1746], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0472], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  35000
# alpha:  Parameter containing:
# tensor([0.1753], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0477], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  36000
# alpha:  Parameter containing:
# tensor([0.1775], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0454], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  37000
# alpha:  Parameter containing:
# tensor([0.1767], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0463], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  38000
# alpha:  Parameter containing:
# tensor([0.1753], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0471], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  39000
# alpha:  Parameter containing:
# tensor([0.1749], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0486], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  40000
# alpha:  Parameter containing:
# tensor([0.1754], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0460], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  41000
# alpha:  Parameter containing:
# tensor([0.1755], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0465], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  42000
# alpha:  Parameter containing:
# tensor([0.1754], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0459], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  43000
# alpha:  Parameter containing:
# tensor([0.1750], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0472], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  44000
# alpha:  Parameter containing:
# tensor([0.1752], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0465], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  45000
# alpha:  Parameter containing:
# tensor([0.1766], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0466], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  46000
# alpha:  Parameter containing:
# tensor([0.1760], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0473], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  47000
# alpha:  Parameter containing:
# tensor([0.1753], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0477], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  48000
# alpha:  Parameter containing:
# tensor([0.1749], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0475], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  49000
# alpha:  Parameter containing:
# tensor([0.1757], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0471], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  50000
# alpha:  Parameter containing:
# tensor([0.1752], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0478], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  51000
# alpha:  Parameter containing:
# tensor([0.1756], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0471], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  52000
# alpha:  Parameter containing:
# tensor([0.1750], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0475], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  53000
# alpha:  Parameter containing:
# tensor([0.1766], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0464], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  54000
# alpha:  Parameter containing:
# tensor([0.1768], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0465], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  55000
# alpha:  Parameter containing:
# tensor([0.1761], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0468], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  56000
# alpha:  Parameter containing:
# tensor([0.1757], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0475], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  57000
# alpha:  Parameter containing:
# tensor([0.1741], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0479], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  58000
# alpha:  Parameter containing:
# tensor([0.1756], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0463], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  59000
# alpha:  Parameter containing:
# tensor([0.1752], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0479], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  60000
# alpha:  Parameter containing:
# tensor([0.1742], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0476], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  61000
# alpha:  Parameter containing:
# tensor([0.1774], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0453], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  62000
# alpha:  Parameter containing:
# tensor([0.1754], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0461], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  63000
# alpha:  Parameter containing:
# tensor([0.1760], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0473], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  64000
# alpha:  Parameter containing:
# tensor([0.1755], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0465], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  65000
# alpha:  Parameter containing:
# tensor([0.1760], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0464], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  66000
# alpha:  Parameter containing:
# tensor([0.1746], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0476], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  67000
# alpha:  Parameter containing:
# tensor([0.1748], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0477], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  68000
# alpha:  Parameter containing:
# tensor([0.1744], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0475], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  69000
# alpha:  Parameter containing:
# tensor([0.1739], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0474], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  70000
# alpha:  Parameter containing:
# tensor([0.1757], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0461], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  71000
# alpha:  Parameter containing:
# tensor([0.1751], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0460], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  72000
# alpha:  Parameter containing:
# tensor([0.1761], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0464], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  73000
# alpha:  Parameter containing:
# tensor([0.1739], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0474], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  74000
# alpha:  Parameter containing:
# tensor([0.1743], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0475], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  75000
# alpha:  Parameter containing:
# tensor([0.1744], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0469], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  76000
# alpha:  Parameter containing:
# tensor([0.1749], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0468], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  77000
# alpha:  Parameter containing:
# tensor([0.1738], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0476], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  78000
# alpha:  Parameter containing:
# tensor([0.1750], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0474], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  79000
# alpha:  Parameter containing:
# tensor([0.1732], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0486], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  80000
# alpha:  Parameter containing:
# tensor([0.1751], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0468], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  81000
# alpha:  Parameter containing:
# tensor([0.1734], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0474], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  82000
# alpha:  Parameter containing:
# tensor([0.1754], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0457], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  83000
# alpha:  Parameter containing:
# tensor([0.1758], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0460], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  84000
# alpha:  Parameter containing:
# tensor([0.1753], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0461], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  85000
# alpha:  Parameter containing:
# tensor([0.1764], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0450], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  86000
# alpha:  Parameter containing:
# tensor([0.1740], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0462], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  87000
# alpha:  Parameter containing:
# tensor([0.1749], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0463], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  88000
# alpha:  Parameter containing:
# tensor([0.1752], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0465], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  89000
# alpha:  Parameter containing:
# tensor([0.1742], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0467], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  90000
# alpha:  Parameter containing:
# tensor([0.1741], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0473], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  91000
# alpha:  Parameter containing:
# tensor([0.1720], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0482], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  92000
# alpha:  Parameter containing:
# tensor([0.1745], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0473], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  93000
# alpha:  Parameter containing:
# tensor([0.1730], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0475], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  94000
# alpha:  Parameter containing:
# tensor([0.1733], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0470], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  95000
# alpha:  Parameter containing:
# tensor([0.1736], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0474], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  96000
# alpha:  Parameter containing:
# tensor([0.1744], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0467], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  97000
# alpha:  Parameter containing:
# tensor([0.1731], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0472], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  98000
# alpha:  Parameter containing:
# tensor([0.1746], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0461], dtype=torch.float64, requires_grad=True)
# #################################
#
# Epoch  99000
# alpha:  Parameter containing:
# tensor([0.1749], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0460], dtype=torch.float64, requires_grad=True)
# #################################
# Wall time: 8min 42s

# %%
plt.plot(dinn.losses, color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss')
print('total loss', dinn.losses[-1])
print('alpha: ', dinn.alpha)
print('beta:', dinn.beta)
# Out:
# total loss 0.0008796997722450002
# alpha:  Parameter containing:
# tensor([0.1751], dtype=torch.float64, requires_grad=True)
# beta: Parameter containing:
# tensor([0.0463], dtype=torch.float64, requires_grad=True)

# %%
fig = plt.figure(figsize=(20,20))

ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')


ax.scatter(sidr_data[0], sidr_data[1], color = 'red', label='Susceptible Data', s=15)
ax.plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'pink', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax.scatter(sidr_data[0], sidr_data[2], color = 'violet', label='Infected Data', s=15)
ax.plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'dodgerblue', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

# ax.scatter(sidr_data[0], sidr_data[4], color = 'black', label='Dead Data', s=15)
# ax.plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax.scatter(sidr_data[0], sidr_data[3], color = 'darkorchid', label='Recovered Data', s=15)
ax.plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')


ax.set_xlabel('Time /weeks',size = 10)
ax.set_ylabel('Number',size = 20)
#ax.set_ylim([-1,50])
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
plt.xticks(size = 10)
plt.yticks(size = 20)
# ax.grid(b=True, which='major', c='black', lw=2.2, ls=15-')
legend = ax.legend(prop={'size':20})
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('output_5')
plt.show()

# %%
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

fig, ax = plt.subplots(2, 2, figsize = (12,12))

for i in range(2):
    for j in range(2):
        ax[i, j].set_facecolor('xkcd:white')


train_day = 35

ax[0, 0].scatter(sidr_data[0][:train_day], sidr_data[1][:train_day], c = 'black', alpha=0.5, lw=2, label='Susceptible Data')
ax[0, 0].scatter(sidr_data[0][train_day:], sidr_data[1][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 0].plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax[0, 1].scatter(sidr_data[0][:train_day], sidr_data[2][:train_day], c = 'violet', alpha=0.5, lw=2, label='Infected Data')
ax[0, 1].scatter(sidr_data[0][train_day:], sidr_data[2][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 1].plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'black', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

# ax[1, 0].scatter(sidr_data[0][:train_day], sidr_data[4][:train_day], c = 'black', alpha=0.5, lw=2, label='Dead Data')
# ax[1, 0].scatter(sidr_data[0][train_day:], sidr_data[4][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
# ax[1, 0].plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax[1, 1].scatter(sidr_data[0][:train_day], sidr_data[3][:train_day], c = 'blue', alpha=0.5, lw=2, label='Recovered Data')
ax[1, 1].scatter(sidr_data[0][train_day:], sidr_data[3][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 1].plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')

for i in range(2):
    for j in range(2):
        ax[i, j].set_xlabel('Time /days',size = 20)
        ax[i, j].set_ylabel('Number',size = 20)
        ax[i, j].yaxis.set_tick_params(length=0)
        ax[i, j].xaxis.set_tick_params(length=0)
        legend = ax[i, j].legend(prop={'size':18})
        legend.get_frame().set_alpha(0.5)
        for spine in ('top', 'right', 'bottom', 'left'):
            ax[i, j].spines[spine].set_visible(False)
plt.savefig('output_5_2')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
