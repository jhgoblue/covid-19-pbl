# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

sidr_data = genfromtxt('svidr_age2_sim.csv', delimiter=',') #in the form of [t,S,V,I,D,R]

torch.manual_seed(1234)

# %%
sidr_data.shape
# Out:
# (11, 100)

# %%
# %%time

PATH = 'svidr_norm_simple' 

class DINN(nn.Module):
    def __init__(self, t, S1_data, S2_data, V1_data, V2_data, I1_data, I2_data, 
                D1_data, D2_data, R1_data, R2_data): #[t,S,V,I,D,R]
        super(DINN, self).__init__()
        self.N = 3e8 #population size
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S1 = torch.tensor(S1_data)
        self.V1 = torch.tensor(V1_data)
        self.I1 = torch.tensor(I1_data)
        self.D1 = torch.tensor(D1_data)
        self.R1 = torch.tensor(R1_data)
        self.S2 = torch.tensor(S2_data)
        self.V2 = torch.tensor(V2_data)
        self.I2 = torch.tensor(I2_data)
        self.D2 = torch.tensor(D2_data)
        self.R2 = torch.tensor(R2_data)

        self.losses = []
        self.save = 2 #which file to save to

        self.alpha_tilda = torch.nn.Parameter(torch.rand(1,requires_grad=True))
        self.beta_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.sigma_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.lbda_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.rho_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.M00_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.M01_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.M11_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        
        #find values for normalization
        self.S1_max, self.S2_max = max(self.S1), max(self.S2)
        self.V1_max, self.V2_max = max(self.V1), max(self.V2)
        self.I1_max, self.I2_max = max(self.I1), max(self.I2)
        self.D1_max, self.D2_max = max(self.D1), max(self.D2)
        self.R1_max, self.R2_max = max(self.R1), max(self.R2)
        self.S1_min, self.S2_min = min(self.S1), min(self.S2)
        self.V1_min, self.V2_min = min(self.V1), min(self.V2)
        self.I1_min, self.I2_min = min(self.I1), min(self.I2)
        self.D1_min, self.D2_min = min(self.D1), min(self.D2)
        self.R1_min, self.R2_min = min(self.R1), min(self.R2)

        #normalize
        self.S1_hat = (self.S1 - self.S1_min) / (self.S1_max - self.S1_min)
        self.V1_hat = (self.V1 - self.V1_min) / (self.V1_max - self.V1_min)
        self.I1_hat = (self.I1 - self.I1_min) / (self.I1_max - self.I1_min)
        self.D1_hat = (self.D1 - self.D1_min) / (self.D1_max - self.D1_min)
        self.R1_hat = (self.R1 - self.R1_min) / (self.R1_max - self.R1_min)

        self.S2_hat = (self.S2 - self.S2_min) / (self.S2_max - self.S2_min)
        self.V2_hat = (self.V2 - self.V2_min) / (self.V2_max - self.V2_min)
        self.I2_hat = (self.I2 - self.I2_min) / (self.I2_max - self.I2_min)
        self.D2_hat = (self.D2 - self.D2_min) / (self.D2_max - self.D2_min)
        self.R2_hat = (self.R2 - self.R2_min) / (self.R2_max - self.R2_min)

        #matrices (x10 for S,V,I,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 10)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 10)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 10)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 10)); self.m4[:, 3] = 1
        self.m5 = torch.zeros((len(self.t), 10)); self.m5[:, 4] = 1
        self.m6 = torch.zeros((len(self.t), 10)); self.m6[:, 5] = 1
        self.m7 = torch.zeros((len(self.t), 10)); self.m7[:, 6] = 1
        self.m8 = torch.zeros((len(self.t), 10)); self.m8[:, 7] = 1
        self.m9 = torch.zeros((len(self.t), 10)); self.m9[:, 8] = 1
        self.m10 = torch.zeros((len(self.t), 10)); self.m10[:, 9] = 1

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha_tilda, self.beta_tilda, self.sigma_tilda, self.lbda_tilda, self.rho_tilda, 
                                 self.M00_tilda, self.M01_tilda, self.M11_tilda]))


    @property
    def alpha(self):
        return torch.tanh(self.alpha_tilda) * 3.5e-2

    @property
    def beta(self):
        return torch.tanh(self.beta_tilda) *0.01 + 0.03
    
    @property
    def sigma(self):
        return torch.tanh(self.sigma_tilda) *0.1 + 0.5

    @property
    def lbda(self):
        return torch.tanh(self.lbda_tilda) *0.002
    
    @property
    def rho(self):
        return torch.tanh(self.rho_tilda)*0.1 + 0.1

    @property
    def M00(self):
        return torch.tanh(self.M00_tilda)*0.1 + 20.7

    @property
    def M01(self):
        return torch.tanh(self.M01_tilda)*0.1 + 6.3  
    
    @property
    def M11(self):
        return torch.tanh(self.M11_tilda)*0.1 + 10.4
    

    #nets
    class Net_sidr(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()
            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
            self.fc5=nn.Linear(20, 20)
            self.fc6=nn.Linear(20, 20)
            self.fc7=nn.Linear(20, 20)
            self.fc8=nn.Linear(20, 20)
            self.out=nn.Linear(20, 10) #outputs S, V, I, D, R

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            sidr=F.relu(self.fc5(sidr))
            sidr=F.relu(self.fc6(sidr))
            sidr=F.relu(self.fc7(sidr))
            sidr=F.relu(self.fc8(sidr))
            sidr=self.out(sidr)
            return sidr
            
    def net_f(self, t_batch):
        sidr_hat = self.net_sidr(t_batch)

        S1_hat, V1_hat, I1_hat, D1_hat, R1_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3], sidr_hat[:,4]
        S2_hat, V2_hat, I2_hat, D2_hat, R2_hat = sidr_hat[:,5], sidr_hat[:,6], sidr_hat[:,7], sidr_hat[:,8], sidr_hat[:,9]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        S1_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        sidr_hat.backward(self.m6, retain_graph=True)
        S2_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #V_t
        sidr_hat.backward(self.m2, retain_graph=True)
        V1_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        sidr_hat.backward(self.m7, retain_graph=True)
        V2_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_t
        sidr_hat.backward(self.m3, retain_graph=True)
        I1_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        sidr_hat.backward(self.m8, retain_graph=True)
        I2_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #D_t
        sidr_hat.backward(self.m4, retain_graph=True)
        D1_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        sidr_hat.backward(self.m9, retain_graph=True)
        D2_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m5, retain_graph=True)
        R1_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        sidr_hat.backward(self.m10, retain_graph=True)
        R2_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S1 = self.S1_min + (self.S1_max - self.S1_min) * S1_hat
        V1 = self.V1_min + (self.V1_max - self.V1_min) * V1_hat
        I1 = self.I1_min + (self.I1_max - self.I1_min) * I1_hat
        D1 = self.D1_min + (self.D1_max - self.D1_min) * D1_hat      
        R1 = self.R1_min + (self.R1_max - self.R1_min) * R1_hat

        S2 = self.S2_min + (self.S2_max - self.S2_min) * S2_hat
        V2 = self.V2_min + (self.V2_max - self.V2_min) * V2_hat
        I2 = self.I2_min + (self.I2_max - self.I2_min) * I2_hat
        D2 = self.D2_min + (self.D2_max - self.D2_min) * D2_hat      
        R2 = self.R2_min + (self.R2_max - self.R2_min) * R2_hat

        f1_hat = S1_hat_t - (-self.beta/self.N * S1 * (self.M00*I1+self.M01*I2) - self.alpha * S1)  / (self.S1_max - self.S1_min)
        f2_hat = V1_hat_t - (self.alpha * S1 - self.sigma * self.beta/self.N * V1 * (self.M00*I1+self.M01*I2))  / (self.V1_max - self.V1_min)
        f3_hat = I1_hat_t - (self.beta/self.N * S1 * (self.M00*I1+self.M01*I2) + self.sigma * self.beta/self.N * V1 * (self.M00*I1+self.M01*I2) - self.lbda * I1 - self.rho * I1 ) / (self.I1_max - self.I1_min)
        f4_hat = D1_hat_t - (self.lbda * I1) / (self.D1_max - self.D1_min)
        f5_hat = R1_hat_t - (self.rho * I1 ) / (self.R1_max - self.R1_min)
        f6_hat = S2_hat_t - (-self.beta/self.N * S2 * (self.M01*I1+self.M11*I2) - self.alpha * S2)  / (self.S2_max - self.S2_min)
        f7_hat = V2_hat_t - (self.alpha * S2 - self.sigma * self.beta/self.N * V2 * (self.M01*I1+self.M11*I2))  / (self.V2_max - self.V2_min)
        f8_hat = I2_hat_t - (self.beta/self.N * S2 * (self.M01*I1+self.M11*I2) + self.sigma * self.beta/self.N * V2 * (self.M01*I1+self.M11*I2) - self.lbda * I2 - self.rho * I2 ) / (self.I2_max - self.I2_min)
        f9_hat = D2_hat_t - (self.lbda * I2) / (self.D2_max - self.D2_min)
        f10_hat = R2_hat_t - (self.rho * I2 ) / (self.R2_max - self.R2_min)

        return f1_hat, f2_hat, f3_hat, f4_hat, f5_hat, f6_hat, f7_hat, f8_hat, f9_hat, f10_hat, S1_hat, V1_hat, I1_hat, D1_hat, R1_hat, S2_hat, V2_hat, I2_hat, D2_hat, R2_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
        self.losses = checkpoint['losses']

      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S1_pred_list, V1_pred_list, I1_pred_list, D1_pred_list, R1_pred_list = [], [], [], [], []
        S2_pred_list, V2_pred_list, I2_pred_list, D2_pred_list, R2_pred_list = [], [], [], [], []
        
        f1, f2, f3, f4, f5, f6, f7, f8, f9, f10, S1_pred, V1_pred, I1_pred, D1_pred, R1_pred, S2_pred, V2_pred, I2_pred, D2_pred, R2_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S1_pred_list.append(self.S1_min + (self.S1_max - self.S1_min) * S1_pred)
        V1_pred_list.append(self.V1_min + (self.V1_max - self.V1_min) * V1_pred) 
        I1_pred_list.append(self.I1_min + (self.I1_max - self.I1_min) * I1_pred)
        D1_pred_list.append(self.D1_min + (self.D1_max - self.D1_min) * D1_pred)
        R1_pred_list.append(self.R1_min + (self.R1_max - self.R1_min) * R1_pred)
        S2_pred_list.append(self.S2_min + (self.S2_max - self.S2_min) * S2_pred)
        V2_pred_list.append(self.V2_min + (self.V2_max - self.V2_min) * V2_pred) 
        I2_pred_list.append(self.I2_min + (self.I2_max - self.I2_min) * I2_pred)
        D2_pred_list.append(self.D2_min + (self.D2_max - self.D2_min) * D2_pred)
        R2_pred_list.append(self.R2_min + (self.R2_max - self.R2_min) * R2_pred)

        train_day = 90

        loss = (torch.mean(torch.square(self.S1_hat[:train_day] - S1_pred[:train_day]))+ 
                torch.mean(torch.square(self.V1_hat[:train_day] - V1_pred[:train_day]))+
                torch.mean(torch.square(self.I1_hat[:train_day] - I1_pred[:train_day]))+
                torch.mean(torch.square(self.D1_hat[:train_day] - D1_pred[:train_day]))+
                torch.mean(torch.square(self.R1_hat[:train_day] - R1_pred[:train_day]))+
                torch.mean(torch.square(self.S2_hat[:train_day] - S2_pred[:train_day]))+ 
                torch.mean(torch.square(self.V2_hat[:train_day] - V2_pred[:train_day]))+
                torch.mean(torch.square(self.I2_hat[:train_day] - I2_pred[:train_day]))+
                torch.mean(torch.square(self.D2_hat[:train_day] - D2_pred[:train_day]))+
                torch.mean(torch.square(self.R2_hat[:train_day] - R2_pred[:train_day]))+
                torch.mean(torch.square(f1[:train_day]))+
                torch.mean(torch.square(f2[:train_day]))+
                torch.mean(torch.square(f3[:train_day]))+
                torch.mean(torch.square(f4[:train_day]))+
                torch.mean(torch.square(f5[:train_day]))+
                torch.mean(torch.square(f6[:train_day]))+
                torch.mean(torch.square(f7[:train_day]))+
                torch.mean(torch.square(f8[:train_day]))+
                torch.mean(torch.square(f9[:train_day]))+
                torch.mean(torch.square(f10[:train_day]))
                ) 

        #loss.backward(retain_graph=True)
        loss.backward()
        self.optimizer.step()
        self.scheduler.step(loss) 
        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)
          print('alpha: (goal 3.5e-3 ', self.alpha)
          print('beta: (goal 0.03 ', self.beta)
          print('sigma: (goal 0.5 ', self.sigma)
          print('lbda: (goal 1e-3 ', self.lbda)
          print('rho: (goal 0.1 ', self.rho)
          print('M00: (goal 20.7 ', self.M00)
          print('M01: (goal 6.3 ', self.M01)
          print('M11: (goal 10.4 ', self.M11)
          print('#################################') 

      return S1_pred_list, V1_pred_list, I1_pred_list, D1_pred_list, R1_pred_list, S2_pred_list, V2_pred_list, I2_pred_list, D2_pred_list, R2_pred_list
# Out:
# Wall time: 0 ns

# %%
# %%time

dinn = DINN(sidr_data[0], sidr_data[1], sidr_data[2], sidr_data[3], sidr_data[4], sidr_data[5], 
            sidr_data[6], sidr_data[7], sidr_data[8], sidr_data[9], sidr_data[10]) #in the form of [t,S,V,I,D,R]

learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

# scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-6, max_lr=1e-3, step_size_up=1000, mode="exp_range", gamma=0.85, cycle_momentum=False)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(dinn.optimizer, mode='min', factor=0.1, patience=1000, min_lr=1e-9, eps=1e-8)

dinn.scheduler = scheduler

nepochs = int(4e5)

S1_pred_list, V1_pred_list, I1_pred_list, D1_pred_list, R1_pred_list, S2_pred_list, V2_pred_list, I2_pred_list, D2_pred_list, R2_pred_list = dinn.train(nepochs) #train
# Out:
# starting training...
#
#
# Epoch  0
# alpha: (goal 3.5e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0338], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5254], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1058], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7605], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.3052], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4437], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  1000
# alpha: (goal 3.5e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0339], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5265], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1045], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7612], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.3038], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4428], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  2000
# alpha: (goal 3.5e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0340], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5274], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1033], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7616], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.3026], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4436], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  3000
# alpha: (goal 3.5e-3  tensor([0.0006], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0340], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5279], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1031], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7616], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.3026], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4439], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  4000
# alpha: (goal 3.5e-3  tensor([0.0012], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0341], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5286], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1028], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7615], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.3029], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4447], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  5000
# alpha: (goal 3.5e-3  tensor([0.0015], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0340], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5288], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1024], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7608], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.3025], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4456], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  6000
# alpha: (goal 3.5e-3  tensor([0.0014], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0338], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5272], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1031], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7597], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.3005], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4459], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  7000
# alpha: (goal 3.5e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0337], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5255], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1048], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7585], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2987], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4444], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  8000
# alpha: (goal 3.5e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0335], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5241], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1062], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7576], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2972], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4431], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  9000
# alpha: (goal 3.5e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0334], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5230], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1073], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7568], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2960], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4420], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  10000
# alpha: (goal 3.5e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0334], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5221], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1081], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7562], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2951], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4412], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  11000
# alpha: (goal 3.5e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0333], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5213], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1087], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7556], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2943], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4406], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  12000
# alpha: (goal 3.5e-3  tensor([0.0011], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0332], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5205], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1092], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7551], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2936], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4399], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  13000
# alpha: (goal 3.5e-3  tensor([0.0014], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0331], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5194], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1100], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7545], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2926], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4391], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  14000
# alpha: (goal 3.5e-3  tensor([0.0017], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0330], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5182], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1112], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7537], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2916], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4381], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  15000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0329], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5170], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1125], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7528], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2903], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4371], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  16000
# alpha: (goal 3.5e-3  tensor([0.0025], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0328], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5158], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1137], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7519], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2892], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4360], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  17000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0327], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5147], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1148], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7511], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2881], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4351], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  18000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0326], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5138], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1156], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7504], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2872], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4343], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  19000
# alpha: (goal 3.5e-3  tensor([0.0034], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0325], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5129], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1163], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7498], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2864], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4336], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  20000
# alpha: (goal 3.5e-3  tensor([0.0036], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0325], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5123], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1167], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7492], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2858], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4332], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  21000
# alpha: (goal 3.5e-3  tensor([0.0036], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0324], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5118], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1166], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7487], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2853], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4330], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  22000
# alpha: (goal 3.5e-3  tensor([0.0037], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0324], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5115], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1157], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7483], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2849], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4331], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  23000
# alpha: (goal 3.5e-3  tensor([0.0037], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0324], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5116], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1145], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7479], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2848], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4337], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  24000
# alpha: (goal 3.5e-3  tensor([0.0037], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0324], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5124], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1134], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7477], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2850], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4346], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  25000
# alpha: (goal 3.5e-3  tensor([0.0036], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0324], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5133], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1124], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7475], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2854], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4353], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  26000
# alpha: (goal 3.5e-3  tensor([0.0036], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0324], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5137], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1116], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7472], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2856], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4357], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  27000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0325], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5144], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1107], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7471], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2863], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4364], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  28000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0325], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5154], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1098], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7474], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2873], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4371], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  29000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0326], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5163], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1089], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7478], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2882], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4379], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  30000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0327], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5170], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1081], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7482], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2889], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4384], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  31000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0327], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5171], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1073], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7482], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2892], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4387], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  32000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0327], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5166], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1066], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7479], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2890], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4385], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  33000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0326], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5156], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1060], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7473], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2883], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4380], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  34000
# alpha: (goal 3.5e-3  tensor([0.0036], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0325], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5145], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1054], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7466], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2873], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4371], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  35000
# alpha: (goal 3.5e-3  tensor([0.0036], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0324], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5134], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1049], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7458], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2862], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4361], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  36000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0323], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5123], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1044], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7451], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2852], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4352], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  37000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0322], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5112], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1042], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7443], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2842], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4343], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  38000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0321], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5102], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1040], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7437], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2833], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4335], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  39000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0320], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5093], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1037], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7430], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2824], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4326], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  40000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0319], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5083], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1034], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7424], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2815], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4318], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  41000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0319], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5074], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1031], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7418], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2807], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4309], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  42000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0318], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5064], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1027], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7412], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2798], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4301], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  43000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0316], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5052], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1037], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7401], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2787], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4292], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  44000
# alpha: (goal 3.5e-3  tensor([0.0034], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0315], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5043], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1041], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7393], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2778], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4285], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  45000
# alpha: (goal 3.5e-3  tensor([0.0034], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0315], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5034], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1039], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7385], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2769], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4277], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  46000
# alpha: (goal 3.5e-3  tensor([0.0034], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0314], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5025], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1034], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7377], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2761], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4270], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  47000
# alpha: (goal 3.5e-3  tensor([0.0034], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0313], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5016], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1029], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7370], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2753], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4262], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  48000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0312], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.5006], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1025], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7362], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2744], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4254], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  49000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0311], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4998], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1021], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7354], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2736], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4247], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  50000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0310], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4990], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1018], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7347], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2728], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4239], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  51000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0309], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4981], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1014], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7339], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2720], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4232], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  52000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0308], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4973], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7332], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2712], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4225], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  53000
# alpha: (goal 3.5e-3  tensor([0.0035], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0307], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4964], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7324], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2705], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4218], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  54000
# alpha: (goal 3.5e-3  tensor([0.0037], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4957], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1003], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7316], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2697], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4212], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  55000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1002], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7312], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2693], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4209], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  56000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7312], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2693], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  57000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  58000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  59000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  60000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  61000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  62000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  63000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  64000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  65000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  66000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  67000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  68000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  69000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  70000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  71000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  72000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  73000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  74000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  75000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  76000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  77000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  78000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  79000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  80000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  81000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  82000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  83000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  84000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  85000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  86000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  87000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  88000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  89000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  90000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  91000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  92000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0306], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4955], grad_fn=<AddBackward0>)
# ...
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  370000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  371000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  372000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  373000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  374000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  375000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  376000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  377000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  378000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  379000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  380000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  381000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  382000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  383000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  384000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  385000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  386000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  387000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  388000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  389000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  390000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  391000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  392000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  393000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  394000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  395000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  396000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  397000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  398000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
#
# Epoch  399000
# alpha: (goal 3.5e-3  tensor([0.0039], grad_fn=<MulBackward0>)
# beta: (goal 0.03  tensor([0.0305], grad_fn=<AddBackward0>)
# sigma: (goal 0.5  tensor([0.4956], grad_fn=<AddBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1001], grad_fn=<AddBackward0>)
# M00: (goal 20.7  tensor([20.7311], grad_fn=<AddBackward0>)
# M01: (goal 6.3  tensor([6.2692], grad_fn=<AddBackward0>)
# M11: (goal 10.4  tensor([10.4208], grad_fn=<AddBackward0>)
# #################################
# Wall time: 1h 7min 4s

# %%
plt.plot(dinn.losses, color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss')
print('total loss: ', dinn.losses[-1])
# Out:
# total loss:  0.0001337714867589814

# %%
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

fig, ax = plt.subplots(2, 5, figsize = (12,12))

for i in range(2):
    for j in range(5):
        ax[i, j].set_facecolor('xkcd:white')


train_day = 90

ax[0, 0].scatter(sidr_data[0][:train_day], sidr_data[1][:train_day], c = 'black', alpha=0.5, lw=2, label='Susceptible1 Data')
ax[0, 0].scatter(sidr_data[0][train_day:], sidr_data[1][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 0].plot(sidr_data[0], S1_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible1 Prediction', linestyle='dashed')

ax[0, 1].scatter(sidr_data[0][:train_day], sidr_data[3][:train_day], c = 'black', alpha=0.5, lw=2, label='Vaccinated1 Data')
ax[0, 1].scatter(sidr_data[0][train_day:], sidr_data[3][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 1].plot(sidr_data[0], V1_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Vaccinated1 Prediction', linestyle='dashed')

ax[0, 2].scatter(sidr_data[0][:train_day], sidr_data[5][:train_day], c = 'violet', alpha=0.5, lw=2, label='Infected1 Data')
ax[0, 2].scatter(sidr_data[0][train_day:], sidr_data[5][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 2].plot(sidr_data[0], I1_pred_list[0].detach().numpy(), 'black', alpha=0.9, lw=2, label='Infected1 Prediction', linestyle='dashed')

ax[0, 3].scatter(sidr_data[0][:train_day], sidr_data[7][:train_day], c = 'black', alpha=0.5, lw=2, label='Dead1 Data')
ax[0, 3].scatter(sidr_data[0][train_day:], sidr_data[7][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 3].plot(sidr_data[0], D1_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead1 Prediction', linestyle='dashed')

ax[0, 4].scatter(sidr_data[0][:train_day], sidr_data[9][:train_day], c = 'blue', alpha=0.5, lw=2, label='Recovered1 Data')
ax[0, 4].scatter(sidr_data[0][train_day:], sidr_data[9][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 4].plot(sidr_data[0], R1_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered1 Prediction', linestyle='dashed')

ax[1, 0].scatter(sidr_data[0][:train_day], sidr_data[2][:train_day], c = 'black', alpha=0.5, lw=2, label='Susceptible2 Data')
ax[1, 0].scatter(sidr_data[0][train_day:], sidr_data[2][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 0].plot(sidr_data[0], S2_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible2 Prediction', linestyle='dashed')

ax[1, 1].scatter(sidr_data[0][:train_day], sidr_data[4][:train_day], c = 'black', alpha=0.5, lw=2, label='Vaccinated2 Data')
ax[1, 1].scatter(sidr_data[0][train_day:], sidr_data[4][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 1].plot(sidr_data[0], V2_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Vaccinated2 Prediction', linestyle='dashed')

ax[1, 2].scatter(sidr_data[0][:train_day], sidr_data[6][:train_day], c = 'violet', alpha=0.5, lw=2, label='Infected2 Data')
ax[1, 2].scatter(sidr_data[0][train_day:], sidr_data[6][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 2].plot(sidr_data[0], I2_pred_list[0].detach().numpy(), 'black', alpha=0.9, lw=2, label='Infected2 Prediction', linestyle='dashed')

ax[1, 3].scatter(sidr_data[0][:train_day], sidr_data[8][:train_day], c = 'black', alpha=0.5, lw=2, label='Dead2 Data')
ax[1, 3].scatter(sidr_data[0][train_day:], sidr_data[8][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 3].plot(sidr_data[0], D2_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead2 Prediction', linestyle='dashed')

ax[1, 4].scatter(sidr_data[0][:train_day], sidr_data[10][:train_day], c = 'blue', alpha=0.5, lw=2, label='Recovered2 Data')
ax[1, 4].scatter(sidr_data[0][train_day:], sidr_data[10][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 4].plot(sidr_data[0], R2_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered2 Prediction', linestyle='dashed')

for i in range(2):
    for j in range(5):
        ax[i, j].set_xlabel('Time /days',size = 20)
        ax[i, j].set_ylabel('Number',size = 20)
        ax[i, j].yaxis.set_tick_params(length=0)
        ax[i, j].xaxis.set_tick_params(length=0)
        legend = ax[i, j].legend(prop={'size':18})
        legend.get_frame().set_alpha(0.5)
        for spine in ('top', 'right', 'bottom', 'left'):
            ax[i, j].spines[spine].set_visible(False)
plt.savefig('age_output1_1.png')
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initial conditions
N = 3e8

init0 = np.array([[N*0.4, N*0.6],
          [0, 0],
          [1, 1],
          [0, 0],
          [0, 0]])
# A grid of time points (in days)
t = np.linspace(0, 500, 100) 

#parameters
alpha = dinn.alpha.detach().numpy().item()
beta = dinn.beta.detach().numpy().item()
sigma = dinn.sigma.detach().numpy().item()
lbda = dinn.lbda.detach().numpy().item()
rho = dinn.rho.detach().numpy().item()
M00 = dinn.M00.detach().numpy().item()
M01 = dinn.M01.detach().numpy().item()
M11 = dinn.M11.detach().numpy().item()
print('alpha: (goal 3.5e-3 ', alpha)
print('beta: (goal 0.03 ', beta)
print('sigma: (goal 0.5 ', sigma)
print('lbda: (goal 1e-3 ', lbda)
print('rho: (goal 0.1 ', rho)
print('M00: (goal 20.7 ', M00)
print('M01: (goal 6.3 ', M01)
print('M11: (goal 10.4 ', M11)
print('#################################')

M = np.array([[M00, M01],
              [M01, M11]])

# The SVIDR model differential equations.
def deriv(y, t, age_num,  alpha, beta, sigma, lbda, rho, M):
    S, V, I, D, R = y[0:2], y[2:4], y[4:6], y[6:8], y[8:10]
    dSdt, dVdt, dIdt, dDdt, dRdt = [], [], [], [], []

    for i in range(age_num):
        dSdt.append( - beta/N * S[i] * M[i, :].dot(I) - alpha * S[i] )
        dVdt.append( alpha * S[i] - sigma * beta/N * V[i] * M[i, :].dot(I) )
        dIdt.append( beta/N * S[i] * M[i, :].dot(I) + sigma * beta/N * V[i] * M[i, :].dot(I) - lbda * I[i] - rho * I[i] )
        dDdt.append( lbda * I[i] )
        dRdt.append( rho * I[i] )

    return dSdt + dVdt + dIdt + dDdt + dRdt

age_num = 2


# Initial conditions vector
y0 = init0.reshape(10, )
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(age_num, alpha, beta, sigma, lbda, rho, M))
S1, S2, V1, V2, I1, I2, D1, D2, R1, R2 = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w', figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, S1, 'purple', alpha=0.5, lw=2, label='Learnable Param Susceptible1', linestyle='dashed')
ax.plot(t, sidr_data[1], 'violet', alpha=0.5, lw=2, label='Susceptible1')

ax.plot(t, V1, 'blue', alpha=0.5, lw=2, label='Learnable Param Vaccinated1', linestyle='dashed')
ax.plot(t, sidr_data[3], 'dodgerblue', alpha=0.5, lw=2, label='Vaccinated1')

ax.plot(t, I1, 'red', alpha=0.5, lw=2, label='Learnable Param Infected1', linestyle='dashed')
ax.plot(t, sidr_data[5], 'pink', alpha=0.5, lw=2, label='Infected1')

ax.plot(t, D1, 'black', alpha=0.5, lw=2, label='Learnable Param Dead1', linestyle='dashed')
ax.plot(t, sidr_data[7], 'grey', alpha=0.5, lw=2, label='Dead1')

ax.plot(t, R1, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Recovered1', linestyle='dashed')
ax.plot(t, sidr_data[9], 'green', alpha=0.5, lw=2, label='Recovered1')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)

plt.savefig('age_output1_2.png')
plt.show()
# Out:
# alpha: (goal 3.5e-3  0.003901244606822729
# beta: (goal 0.03  0.030541840940713882
# sigma: (goal 0.5  0.495626837015152
# lbda: (goal 1e-3  0.0009823405416682363
# rho: (goal 0.1  0.10006200522184372
# M00: (goal 20.7  20.73114585876465
# M01: (goal 6.3  6.269249439239502
# M11: (goal 10.4  10.42082405090332
# #################################

# %%
# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w', figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, S2, 'purple', alpha=0.5, lw=2, label='Learnable Param Susceptible2', linestyle='dashed')
ax.plot(t, sidr_data[2], 'violet', alpha=0.5, lw=2, label='Susceptible2')

ax.plot(t, V2, 'blue', alpha=0.5, lw=2, label='Learnable Param Vaccinated2', linestyle='dashed')
ax.plot(t, sidr_data[4], 'dodgerblue', alpha=0.5, lw=2, label='Vaccinated2')

ax.plot(t, I2, 'red', alpha=0.5, lw=2, label='Learnable Param Infected2', linestyle='dashed')
ax.plot(t, sidr_data[6], 'pink', alpha=0.5, lw=2, label='Infected2')

ax.plot(t, D2, 'black', alpha=0.5, lw=2, label='Learnable Param Dead2', linestyle='dashed')
ax.plot(t, sidr_data[8], 'grey', alpha=0.5, lw=2, label='Dead2')

ax.plot(t, R2, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Recovered2', linestyle='dashed')
ax.plot(t, sidr_data[10], 'green', alpha=0.5, lw=2, label='Recovered2')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)

plt.savefig('age_output1_3.png')
plt.show()

# %%
#calculate relative MSE loss
import math

S_total_loss = 0
S_den = 0
V_total_loss = 0
V_den = 0
I_total_loss = 0
I_den = 0
D_total_loss = 0
D_den = 0
R_total_loss = 0
R_den = 0

for timestep in range(len(t)):
  S_value = sidr_data[1][timestep] - S1[timestep]
  S_total_loss += S_value**2
  S_den += (sidr_data[1][timestep])**2

  V_value = sidr_data[3][timestep] - V1[timestep]
  V_total_loss += V_value**2
  V_den += (sidr_data[3][timestep])**2

  I_value = sidr_data[5][timestep] - I1[timestep]
  I_total_loss += I_value**2
  I_den += (sidr_data[5][timestep])**2

  D_value = sidr_data[7][timestep] - D1[timestep]
  D_total_loss += D_value**2
  D_den += (sidr_data[7][timestep])**2

  R_value = sidr_data[9][timestep] - R1[timestep]
  R_total_loss += R_value**2
  R_den += (sidr_data[9][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)
V_total_loss = math.sqrt(V_total_loss/V_den)
I_total_loss = math.sqrt(I_total_loss/I_den)
D_total_loss = math.sqrt(D_total_loss/D_den)
R_total_loss = math.sqrt(R_total_loss/R_den)

print('S1_total_loss: ', S_total_loss)
print('V1_total_loss: ', V_total_loss)
print('I1_total_loss: ', I_total_loss)
print('D1_total_loss: ', D_total_loss)
print('R1_total_loss: ', R_total_loss)
# Out:
# S1_total_loss:  0.03409331852611049
# V1_total_loss:  0.07225470391341214
# I1_total_loss:  0.07567414974403325
# D1_total_loss:  0.020691611098781083
# R1_total_loss:  0.009558729226312597

# %%
#calculate relative MSE loss
import math

S_total_loss = 0
S_den = 0
V_total_loss = 0
V_den = 0
I_total_loss = 0
I_den = 0
D_total_loss = 0
D_den = 0
R_total_loss = 0
R_den = 0

for timestep in range(len(t)):
  S_value = sidr_data[2][timestep] - S2[timestep]
  S_total_loss += S_value**2
  S_den += (sidr_data[2][timestep])**2

  V_value = sidr_data[4][timestep] - V2[timestep]
  V_total_loss += V_value**2
  V_den += (sidr_data[4][timestep])**2

  I_value = sidr_data[6][timestep] - I2[timestep]
  I_total_loss += I_value**2
  I_den += (sidr_data[6][timestep])**2

  D_value = sidr_data[8][timestep] - D2[timestep]
  D_total_loss += D_value**2
  D_den += (sidr_data[8][timestep])**2

  R_value = sidr_data[10][timestep] - R2[timestep]
  R_total_loss += R_value**2
  R_den += (sidr_data[10][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)
V_total_loss = math.sqrt(V_total_loss/V_den)
I_total_loss = math.sqrt(I_total_loss/I_den)
D_total_loss = math.sqrt(D_total_loss/D_den)
R_total_loss = math.sqrt(R_total_loss/R_den)

print('S2_total_loss: ', S_total_loss)
print('V2_total_loss: ', V_total_loss)
print('I2_total_loss: ', I_total_loss)
print('D2_total_loss: ', D_total_loss)
print('R2_total_loss: ', R_total_loss)
# Out:
# S2_total_loss:  0.03478599546452523
# V2_total_loss:  0.06479867105764768
# I2_total_loss:  0.07074663270290286
# D2_total_loss:  0.021150779448710837
# R2_total_loss:  0.009390876029883378
