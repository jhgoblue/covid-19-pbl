# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

sidr_data = genfromtxt('svidr_sim.csv', delimiter=',') #in the form of [t,S,V,I,D,R]

torch.manual_seed(1234)

# %%
sidr_data.shape
# Out:
# (6, 100)

# %%
# %%time

PATH = 'svidr_norm_simple' 

class DINN(nn.Module):
    def __init__(self, t, S_data, V_data, I_data, D_data, R_data): #[t,S,V,I,D,R]
        super(DINN, self).__init__()
        self.N = 3e8 #population size
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S = torch.tensor(S_data)
        self.V = torch.tensor(V_data)
        self.I = torch.tensor(I_data)
        self.D = torch.tensor(D_data)
        self.R = torch.tensor(R_data)

        self.losses = []
        self.save = 2 #which file to save to

        self.alpha_tilda = torch.nn.Parameter(torch.rand(1,dtype=torch.double, requires_grad=True))
        self.beta_tilda = torch.nn.Parameter(torch.rand(1,dtype=torch.double, requires_grad=True))
        self.sigma_tilda = torch.nn.Parameter(torch.rand(1,dtype=torch.double, requires_grad=True))
        self.lbda_tilda = torch.nn.Parameter(torch.rand(1,dtype=torch.double, requires_grad=True))
        self.rho_tilda = torch.nn.Parameter(torch.rand(1,dtype=torch.double, requires_grad=True))
        
        #find values for normalization
        self.S_max = max(self.S)
        self.V_max = max(self.V)
        self.I_max = max(self.I)
        self.D_max = max(self.D)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.V_min = min(self.V)
        self.I_min = min(self.I)
        self.D_min = min(self.D)
        self.R_min = min(self.R)

        #normalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.V_hat = (self.V - self.V_min) / (self.V_max - self.V_min)
        self.I_hat = (self.I - self.I_min) / (self.I_max - self.I_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)

        #matrices (x5 for S,V,I,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 5)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 5)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 5)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 5)); self.m4[:, 3] = 1
        self.m5 = torch.zeros((len(self.t), 5)); self.m5[:, 4] = 1

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha_tilda, self.beta_tilda, self.sigma_tilda, self.lbda_tilda, self.rho_tilda]))


    @property
    def alpha(self):
        return torch.tanh(self.alpha_tilda) * 3.5e-2

    @property
    def beta(self):
        return torch.tanh(self.beta_tilda) *0.5
    
    @property
    def sigma(self):
        return torch.tanh(self.sigma_tilda) *0.1

    @property
    def lbda(self):
        return torch.tanh(self.lbda_tilda) *0.002
    
    @property
    def rho(self):
        return torch.tanh(self.rho_tilda)*0.5

    #nets
    class Net_sidr(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()
            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
            self.fc5=nn.Linear(20, 20)
            self.fc6=nn.Linear(20, 20)
            self.fc7=nn.Linear(20, 20)
            self.fc8=nn.Linear(20, 20)
            self.out=nn.Linear(20, 5) #outputs S, V, I, D, R

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            sidr=F.relu(self.fc5(sidr))
            sidr=F.relu(self.fc6(sidr))
            sidr=F.relu(self.fc7(sidr))
            sidr=F.relu(self.fc8(sidr))
            sidr=self.out(sidr)
            return sidr
            
    def net_f(self, t_batch):
        sidr_hat = self.net_sidr(t_batch)

        S_hat, V_hat, I_hat, D_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3], sidr_hat[:,4]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #V_t
        sidr_hat.backward(self.m2, retain_graph=True)
        V_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_t
        sidr_hat.backward(self.m3, retain_graph=True)
        I_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #D_t
        sidr_hat.backward(self.m4, retain_graph=True)
        D_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m5, retain_graph=True)
        R_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        V = self.V_min + (self.V_max - self.V_min) * V_hat
        I = self.I_min + (self.I_max - self.I_min) * I_hat
        D = self.D_min + (self.D_max - self.D_min) * D_hat      
        R = self.R_min + (self.R_max - self.R_min) * R_hat

        f1_hat = S_hat_t - (-self.beta/self.N * S * I - self.alpha * S)  / (self.S_max - self.S_min)
        f2_hat = V_hat_t - (self.alpha * S - self.sigma * self.beta/self.N * V * I)  / (self.V_max - self.V_min)
        f3_hat = I_hat_t - (self.beta/self.N * S * I + self.sigma * self.beta/self.N * V * I - self.lbda * I - self.rho * I ) / (self.I_max - self.I_min)
        f4_hat = D_hat_t - (self.lbda * I) / (self.D_max - self.D_min)
        f5_hat = R_hat_t - (self.rho * I ) / (self.R_max - self.R_min)

        return f1_hat, f2_hat, f3_hat, f4_hat, f5_hat, S_hat, V_hat, I_hat, D_hat, R_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
        self.losses = checkpoint['losses']

      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S_pred_list = []
        V_pred_list = []
        I_pred_list = []
        D_pred_list = []
        R_pred_list = []

        f1, f2, f3, f4, f5, S_pred, V_pred, I_pred, D_pred, R_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred)
        V_pred_list.append(self.V_min + (self.V_max - self.V_min) * V_pred) 
        I_pred_list.append(self.I_min + (self.I_max - self.I_min) * I_pred)
        D_pred_list.append(self.D_min + (self.D_max - self.D_min) * D_pred)
        R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

        train_day = 90

        loss = (torch.mean(torch.square(self.S_hat[:train_day] - S_pred[:train_day]))+ 
                torch.mean(torch.square(self.V_hat[:train_day] - V_pred[:train_day]))+
                torch.mean(torch.square(self.I_hat[:train_day] - I_pred[:train_day]))+
                torch.mean(torch.square(self.D_hat[:train_day] - D_pred[:train_day]))+
                torch.mean(torch.square(self.R_hat[:train_day] - R_pred[:train_day]))+
                torch.mean(torch.square(f1[:train_day]))+
                torch.mean(torch.square(f2[:train_day]))+
                torch.mean(torch.square(f3[:train_day]))+
                torch.mean(torch.square(f4[:train_day]))+
                torch.mean(torch.square(f5[:train_day]))
                ) 

        #loss.backward(retain_graph=True)
        loss.backward()
        self.optimizer.step()
        self.scheduler.step() 
        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)
          print('alpha: (goal 3.5e-3 ', self.alpha)
          print('beta: (goal 0.3 ', self.beta)
          print('sigma: (goal 0.05 ', self.sigma)
          print('lbda: (goal 1e-3 ', self.lbda)
          print('rho: (goal 0.1 ', self.rho)
          print('#################################') 

        #loss + model parameters update
        if epoch % 4000 == 9999:
          #checkpoint save
          print('\nSaving model... Loss is: ', loss)
          torch.save({
              'epoch': epoch,
              'model': self.state_dict(),
              'optimizer_state_dict': self.optimizer.state_dict(),
              'scheduler': self.scheduler.state_dict(),
              #'loss': loss,
              'losses': self.losses,
              }, PATH + str(self.save)+'.pt')
          if self.save % 2 > 0: #its on 3
            self.save = 2 #change to 2
          else: #its on 2
            self.save = 3 #change to 3

      return S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list
# Out:
# Wall time: 999 µs

# %%
# %%time

dinn = DINN(sidr_data[0], sidr_data[1], sidr_data[2], sidr_data[3], 
            sidr_data[4], sidr_data[5]) #in the form of [t,S,V,I,D,R]

learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-6, max_lr=1e-3, step_size_up=1000, mode="exp_range", gamma=0.85, cycle_momentum=False)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(dinn.optimizer, mode='min', factor=0.1, patience=1000, min_lr=1e-6, eps=1e-8)


dinn.scheduler = scheduler

nepochs = int(5e5)

# S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train

try: 
  S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
except EOFError:
  if dinn.save == 2:
    dinn.save = 3
    S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
  elif dinn.save == 3:
    dinn.save = 2
    S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
# Out:
# starting training...
#
#
# Epoch  0
# alpha: (goal 3.5e-3  tensor([0.0080], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0393], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0435], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1859], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  1000
# alpha: (goal 3.5e-3  tensor([0.0079], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0398], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0434], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1854], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  2000
# alpha: (goal 3.5e-3  tensor([0.0079], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0405], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0434], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1850], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  3000
# alpha: (goal 3.5e-3  tensor([0.0079], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0411], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0433], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1845], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  4000
# alpha: (goal 3.5e-3  tensor([0.0078], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0418], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0433], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1840], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  5000
# alpha: (goal 3.5e-3  tensor([0.0078], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0423], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0432], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1836], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  6000
# alpha: (goal 3.5e-3  tensor([0.0077], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0428], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0433], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1833], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  7000
# alpha: (goal 3.5e-3  tensor([0.0077], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0433], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0433], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1829], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  8000
# alpha: (goal 3.5e-3  tensor([0.0076], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0438], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0434], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1826], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  9000
# alpha: (goal 3.5e-3  tensor([0.0076], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0442], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0435], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1823], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  10000
# alpha: (goal 3.5e-3  tensor([0.0075], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0446], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0436], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1819], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  11000
# alpha: (goal 3.5e-3  tensor([0.0075], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0450], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0437], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1816], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  12000
# alpha: (goal 3.5e-3  tensor([0.0075], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0454], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0437], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1812], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  13000
# alpha: (goal 3.5e-3  tensor([0.0074], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0458], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0438], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1808], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  14000
# alpha: (goal 3.5e-3  tensor([0.0074], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0464], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0439], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1804], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  15000
# alpha: (goal 3.5e-3  tensor([0.0073], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0469], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0440], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1800], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  16000
# alpha: (goal 3.5e-3  tensor([0.0073], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0475], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0441], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1796], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  17000
# alpha: (goal 3.5e-3  tensor([0.0073], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0480], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0442], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1792], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  18000
# alpha: (goal 3.5e-3  tensor([0.0072], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0484], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0443], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1787], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  19000
# alpha: (goal 3.5e-3  tensor([0.0072], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0489], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0444], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1783], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  20000
# alpha: (goal 3.5e-3  tensor([0.0072], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0494], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0444], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1778], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  21000
# alpha: (goal 3.5e-3  tensor([0.0072], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0500], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0445], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1773], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  22000
# alpha: (goal 3.5e-3  tensor([0.0071], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0506], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0446], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1769], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  23000
# alpha: (goal 3.5e-3  tensor([0.0071], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0511], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0447], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1764], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  24000
# alpha: (goal 3.5e-3  tensor([0.0071], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0516], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0448], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1759], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  25000
# alpha: (goal 3.5e-3  tensor([0.0071], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0521], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0449], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1755], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  26000
# alpha: (goal 3.5e-3  tensor([0.0071], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0525], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0450], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1751], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  27000
# alpha: (goal 3.5e-3  tensor([0.0071], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0530], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0451], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1746], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  28000
# alpha: (goal 3.5e-3  tensor([0.0071], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0535], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0451], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1742], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  29000
# alpha: (goal 3.5e-3  tensor([0.0071], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0540], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0452], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1738], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  30000
# alpha: (goal 3.5e-3  tensor([0.0072], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0545], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0453], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1733], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  31000
# alpha: (goal 3.5e-3  tensor([0.0072], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0550], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0454], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1729], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  32000
# alpha: (goal 3.5e-3  tensor([0.0072], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0555], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0455], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1724], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  33000
# alpha: (goal 3.5e-3  tensor([0.0072], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0560], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0455], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1720], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  34000
# alpha: (goal 3.5e-3  tensor([0.0073], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0565], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0456], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1715], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  35000
# alpha: (goal 3.5e-3  tensor([0.0073], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0570], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0457], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1711], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  36000
# alpha: (goal 3.5e-3  tensor([0.0073], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0575], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0458], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1706], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  37000
# alpha: (goal 3.5e-3  tensor([0.0072], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0580], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0459], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1702], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  38000
# alpha: (goal 3.5e-3  tensor([0.0072], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0586], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0459], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1697], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  39000
# alpha: (goal 3.5e-3  tensor([0.0071], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0591], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0460], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1693], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  40000
# alpha: (goal 3.5e-3  tensor([0.0071], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0596], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0461], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1688], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  41000
# alpha: (goal 3.5e-3  tensor([0.0071], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0601], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0462], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1684], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  42000
# alpha: (goal 3.5e-3  tensor([0.0070], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0606], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0463], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1679], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  43000
# alpha: (goal 3.5e-3  tensor([0.0070], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0611], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0463], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1675], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  44000
# alpha: (goal 3.5e-3  tensor([0.0069], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0616], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0464], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1670], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  45000
# alpha: (goal 3.5e-3  tensor([0.0069], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0622], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0465], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1666], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  46000
# alpha: (goal 3.5e-3  tensor([0.0069], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0627], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0466], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1661], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  47000
# alpha: (goal 3.5e-3  tensor([0.0068], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0632], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0467], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1657], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  48000
# alpha: (goal 3.5e-3  tensor([0.0068], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0637], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0468], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1652], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  49000
# alpha: (goal 3.5e-3  tensor([0.0067], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0642], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0468], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1648], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  50000
# alpha: (goal 3.5e-3  tensor([0.0067], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0648], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0469], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1643], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  51000
# alpha: (goal 3.5e-3  tensor([0.0067], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0653], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0470], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1638], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  52000
# alpha: (goal 3.5e-3  tensor([0.0066], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0658], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0471], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1634], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  53000
# alpha: (goal 3.5e-3  tensor([0.0066], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0663], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0472], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1629], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  54000
# alpha: (goal 3.5e-3  tensor([0.0066], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0668], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0472], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1625], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  55000
# alpha: (goal 3.5e-3  tensor([0.0065], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0674], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0473], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1620], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  56000
# alpha: (goal 3.5e-3  tensor([0.0065], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0679], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0474], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1616], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  57000
# alpha: (goal 3.5e-3  tensor([0.0064], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0684], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0475], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1611], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  58000
# alpha: (goal 3.5e-3  tensor([0.0064], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0689], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0476], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1606], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  59000
# alpha: (goal 3.5e-3  tensor([0.0064], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0694], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0476], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1602], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  60000
# alpha: (goal 3.5e-3  tensor([0.0063], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0699], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0477], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1597], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  61000
# alpha: (goal 3.5e-3  tensor([0.0063], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0704], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0478], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1593], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  62000
# alpha: (goal 3.5e-3  tensor([0.0063], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0709], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0479], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1588], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  63000
# alpha: (goal 3.5e-3  tensor([0.0062], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0714], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0480], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1584], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  64000
# alpha: (goal 3.5e-3  tensor([0.0062], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0719], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0480], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1579], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  65000
# alpha: (goal 3.5e-3  tensor([0.0061], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0724], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0481], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1575], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  66000
# alpha: (goal 3.5e-3  tensor([0.0061], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0729], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0482], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1570], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  67000
# alpha: (goal 3.5e-3  tensor([0.0061], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0734], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0483], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1566], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  68000
# alpha: (goal 3.5e-3  tensor([0.0060], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0739], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0483], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1562], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  69000
# alpha: (goal 3.5e-3  tensor([0.0060], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0744], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0484], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1557], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  70000
# alpha: (goal 3.5e-3  tensor([0.0060], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0749], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0485], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1553], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  71000
# alpha: (goal 3.5e-3  tensor([0.0059], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0754], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0486], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1548], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  72000
# alpha: (goal 3.5e-3  tensor([0.0059], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0759], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0487], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1544], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  73000
# alpha: (goal 3.5e-3  tensor([0.0059], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0764], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0487], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1539], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  74000
# alpha: (goal 3.5e-3  tensor([0.0058], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0769], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0488], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1535], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  75000
# alpha: (goal 3.5e-3  tensor([0.0058], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0774], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0489], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1530], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  76000
# alpha: (goal 3.5e-3  tensor([0.0058], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0779], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0490], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1526], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  77000
# alpha: (goal 3.5e-3  tensor([0.0057], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0784], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0490], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1521], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  78000
# alpha: (goal 3.5e-3  tensor([0.0057], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0788], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0491], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1517], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  79000
# alpha: (goal 3.5e-3  tensor([0.0057], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0793], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0492], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1512], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  80000
# alpha: (goal 3.5e-3  tensor([0.0056], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0798], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0493], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1508], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  81000
# alpha: (goal 3.5e-3  tensor([0.0056], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0803], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0493], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1503], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  82000
# alpha: (goal 3.5e-3  tensor([0.0056], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0808], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0494], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1498], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  83000
# alpha: (goal 3.5e-3  tensor([0.0055], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0813], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0495], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1494], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  84000
# alpha: (goal 3.5e-3  tensor([0.0055], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0818], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0496], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1489], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  85000
# alpha: (goal 3.5e-3  tensor([0.0054], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0823], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0496], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1485], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  86000
# alpha: (goal 3.5e-3  tensor([0.0054], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0827], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0497], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1480], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  87000
# alpha: (goal 3.5e-3  tensor([0.0054], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0832], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0498], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1476], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  88000
# alpha: (goal 3.5e-3  tensor([0.0053], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0837], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0499], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1471], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  89000
# alpha: (goal 3.5e-3  tensor([0.0053], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0842], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0499], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1466], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  90000
# alpha: (goal 3.5e-3  tensor([0.0053], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0847], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0500], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1462], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  91000
# alpha: (goal 3.5e-3  tensor([0.0052], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0852], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0501], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1457], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  92000
# alpha: (goal 3.5e-3  tensor([0.0052], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0857], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0502], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1452], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  93000
# alpha: (goal 3.5e-3  tensor([0.0052], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0862], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0503], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1447], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  94000
# alpha: (goal 3.5e-3  tensor([0.0051], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0867], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0503], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1443], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  95000
# alpha: (goal 3.5e-3  tensor([0.0051], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0872], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0504], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1438], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  96000
# alpha: (goal 3.5e-3  tensor([0.0051], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0876], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0505], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1433], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  97000
# alpha: (goal 3.5e-3  tensor([0.0050], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0881], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0506], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1429], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  98000
# alpha: (goal 3.5e-3  tensor([0.0050], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0886], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0506], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1424], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  99000
# alpha: (goal 3.5e-3  tensor([0.0050], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0891], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0507], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1419], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  100000
# alpha: (goal 3.5e-3  tensor([0.0049], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0896], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0508], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1415], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  101000
# alpha: (goal 3.5e-3  tensor([0.0049], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0901], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0509], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1410], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  102000
# alpha: (goal 3.5e-3  tensor([0.0049], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0906], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0509], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1405], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  103000
# alpha: (goal 3.5e-3  tensor([0.0048], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0911], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0510], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1401], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  104000
# alpha: (goal 3.5e-3  tensor([0.0048], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0916], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0511], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1396], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  105000
# alpha: (goal 3.5e-3  tensor([0.0048], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0921], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0512], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1391], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  106000
# alpha: (goal 3.5e-3  tensor([0.0047], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.0925], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0512], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], dtype=torch.float64, grad_fn=<MulBackward0>)
# ...
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0844], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  465000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2478], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0724], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0846], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  466000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2481], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0725], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0847], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  467000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2485], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0725], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0848], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  468000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2489], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0726], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0850], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  469000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2493], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0726], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0851], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  470000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2496], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0727], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0852], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  471000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2500], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0727], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0853], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  472000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2504], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0728], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0855], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  473000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2507], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0728], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0856], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  474000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2511], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0728], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0857], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  475000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2515], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0729], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0859], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  476000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2519], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0729], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0860], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  477000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2522], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0730], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0861], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  478000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2526], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0730], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0862], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  479000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2530], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0731], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0864], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  480000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2533], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0731], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0865], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  481000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2537], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0731], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0866], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  482000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2541], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0732], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0868], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  483000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2544], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0732], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0869], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  484000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2548], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0733], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0870], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  485000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2552], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0733], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0871], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  486000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2555], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0734], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0873], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  487000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2559], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0734], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0874], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  488000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2563], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0734], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0875], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  489000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2566], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0735], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0876], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  490000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2570], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0735], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0878], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  491000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2574], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0736], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0879], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  492000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2577], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0736], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0880], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  493000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2581], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0737], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0881], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  494000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2584], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0737], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0883], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  495000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2588], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0737], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0884], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  496000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2592], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0738], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0885], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  497000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2595], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0738], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0886], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  498000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2599], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0739], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0888], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
#
# Epoch  499000
# alpha: (goal 3.5e-3  tensor([0.0036], dtype=torch.float64, grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2603], dtype=torch.float64, grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0739], dtype=torch.float64, grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], dtype=torch.float64, grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0889], dtype=torch.float64, grad_fn=<MulBackward0>)
# #################################
# Wall time: 56min 24s

# %%
plt.plot(dinn.losses, color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss'),
# Out:
# (Text(0, 0.5, 'Loss'),)

# %%
fig = plt.figure(figsize=(12,12))

ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')



ax.scatter(sidr_data[0], sidr_data[1], color = 'darkgreen', label='Susceptible Data', s=15)
ax.plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[2], color = 'blue', label='Vaccinated Data', s=15)
ax.plot(sidr_data[0], V_pred_list[0].detach().numpy(), 'lightblue', alpha=0.9, lw=2, label='Vaccinated Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[3], color = 'red', label='Infected Data', s=15)
ax.plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'pink', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[4], color = 'black', label='Dead Data', s=15)
ax.plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'grey', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[5], color = 'green', label='Recovered Data', s=15)
ax.plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'lightgreen', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')


ax.set_xlabel('Time /days',size = 20)
ax.set_ylabel('Number',size = 20)

ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
plt.xticks(size = 20)
plt.yticks(size = 20)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend(prop={'size':20})
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('covid_missing_I.pdf')
plt.show()

# %%
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

fig, ax = plt.subplots(2, 3, figsize = (12,12))

for i in range(2):
    for j in range(3):
        ax[i, j].set_facecolor('xkcd:white')


train_day = 90

ax[0, 0].scatter(sidr_data[0][:train_day], sidr_data[1][:train_day], c = 'black', alpha=0.5, lw=2, label='Susceptible Data')
ax[0, 0].scatter(sidr_data[0][train_day:], sidr_data[1][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 0].plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax[0, 1].scatter(sidr_data[0][:train_day], sidr_data[2][:train_day], c = 'black', alpha=0.5, lw=2, label='Vaccinated Data')
ax[0, 1].scatter(sidr_data[0][train_day:], sidr_data[2][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 1].plot(sidr_data[0], V_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Vaccinated Prediction', linestyle='dashed')

ax[0, 2].scatter(sidr_data[0][:train_day], sidr_data[3][:train_day], c = 'violet', alpha=0.5, lw=2, label='Infected Data')
ax[0, 2].scatter(sidr_data[0][train_day:], sidr_data[3][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 2].plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'black', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

ax[1, 0].scatter(sidr_data[0][:train_day], sidr_data[4][:train_day], c = 'black', alpha=0.5, lw=2, label='Dead Data')
ax[1, 0].scatter(sidr_data[0][train_day:], sidr_data[4][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 0].plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax[1, 1].scatter(sidr_data[0][:train_day], sidr_data[5][:train_day], c = 'blue', alpha=0.5, lw=2, label='Recovered Data')
ax[1, 1].scatter(sidr_data[0][train_day:], sidr_data[5][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 1].plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')

for i in range(2):
    for j in range(3):
        ax[i, j].set_xlabel('Time /days',size = 20)
        ax[i, j].set_ylabel('Number',size = 20)
        ax[i, j].yaxis.set_tick_params(length=0)
        ax[i, j].xaxis.set_tick_params(length=0)
        legend = ax[i, j].legend(prop={'size':18})
        legend.get_frame().set_alpha(0.5)
        for spine in ('top', 'right', 'bottom', 'left'):
            ax[i, j].spines[spine].set_visible(False)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initial conditions
N = 3e8

S0 = N - 1
V0 = 0
I0 = 1
D0 = 0
R0 = 0
# A grid of time points (in days)
t = np.linspace(0, 500, 100) 

#parameters
alpha = dinn.alpha.detach().numpy().item()
beta = dinn.beta.detach().numpy().item()
sigma = dinn.sigma.detach().numpy().item()
lbda = dinn.lbda.detach().numpy().item()
rho = dinn.rho.detach().numpy().item()
print('alpha: (goal 3.5e-3 ', alpha)
print('beta: (goal 0.3 ', beta)
print('sigma: (goal 0.05 ', sigma)
print('lbda: (goal 1e-3 ', lbda)
print('rho: (goal 0.1 ', rho)
print('#################################')

# The SIR model differential equations.
def deriv(y, t, alpha, beta, sigma, lbda, rho):
    S, V, I, D, R = y
    dSdt = - beta/N * S * I - alpha * S
    dVdt = alpha * S - sigma * beta/N * V * I
    dIdt = beta/N * S * I + sigma * beta/N * V * I - lbda * I - rho * I 
    dDdt = lbda * I
    dRdt = rho * I

    return dSdt, dVdt, dIdt, dDdt, dRdt


# Initial conditions vector
y0 = S0, V0, I0, D0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(alpha, beta, sigma, lbda, rho))
S, V, I, D, R = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w', figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, S, 'purple', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
# ax.plot(t, sidr_data[1], 'violet', alpha=0.5, lw=2, label='Susceptible')

ax.plot(t, V, 'blue', alpha=0.5, lw=2, label='Learnable Param Vaccinated', linestyle='dashed')
ax.plot(t, sidr_data[2], 'dodgerblue', alpha=0.5, lw=2, label='Vaccinated')

ax.plot(t, I, 'red', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.plot(t, sidr_data[3], 'pink', alpha=0.5, lw=2, label='Infected')

ax.plot(t, D, 'black', alpha=0.5, lw=2, label='Learnable Param Dead', linestyle='dashed')
ax.plot(t, sidr_data[4], 'grey', alpha=0.5, lw=2, label='Dead')

ax.plot(t, R, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Recovered', linestyle='dashed')
# ax.plot(t, sidr_data[5], 'green', alpha=0.5, lw=2, label='Recovered')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()
# Out:
# alpha: (goal 3.5e-3  0.0035597432084009087
# beta: (goal 0.3  0.2606152289128206
# sigma: (goal 0.05  0.07394081309835503
# lbda: (goal 1e-3  0.0010030021569805742
# rho: (goal 0.1  0.08901669932190359
# #################################

# %%
#calculate relative MSE loss
import math

S_total_loss = 0
S_den = 0
V_total_loss = 0
V_den = 0
I_total_loss = 0
I_den = 0
D_total_loss = 0
D_den = 0
R_total_loss = 0
R_den = 0

for timestep in range(len(t)):
  S_value = sidr_data[1][timestep] - S[timestep]
  S_total_loss += S_value**2
  S_den += (sidr_data[1][timestep])**2

  V_value = sidr_data[1][timestep] - V[timestep]
  V_total_loss += V_value**2
  V_den += (sidr_data[1][timestep])**2

  I_value = sidr_data[3][timestep] - I[timestep]
  I_total_loss += I_value**2
  I_den += (sidr_data[3][timestep])**2

  D_value = sidr_data[4][timestep] - D[timestep]
  D_total_loss += D_value**2
  D_den += (sidr_data[4][timestep])**2

  R_value = sidr_data[5][timestep] - R[timestep]
  R_total_loss += R_value**2
  R_den += (sidr_data[5][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)
V_total_loss = math.sqrt(V_total_loss/V_den)
I_total_loss = math.sqrt(I_total_loss/I_den)
D_total_loss = math.sqrt(D_total_loss/D_den)
R_total_loss = math.sqrt(R_total_loss/R_den)

print('S_total_loss: ', S_total_loss)
print('V_total_loss: ', V_total_loss)
print('I_total_loss: ', I_total_loss)
print('D_total_loss: ', D_total_loss)
print('R_total_loss: ', R_total_loss)
# Out:
# S_total_loss:  0.18895662613740744
# V_total_loss:  1.116998852226249
# I_total_loss:  0.821844515759252
# D_total_loss:  0.1910324080906381
# R_total_loss:  0.2504762089619737
