# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

sidr_data = genfromtxt('svidr_sim.csv', delimiter=',') #in the form of [t,S,V,I,D,R]

torch.manual_seed(1234)

# %%
sidr_data.shape
# Out:
# (6, 100)

# %%
# %%time

PATH = 'svidr_norm_simple' 

class DINN(nn.Module):
    def __init__(self, t, S_data, V_data, I_data, D_data, R_data): #[t,S,V,I,D,R]
        super(DINN, self).__init__()
        self.N = 3e8 #population size
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S = torch.tensor(S_data)
        self.V = torch.tensor(V_data)
        self.I = torch.tensor(I_data)
        self.D = torch.tensor(D_data)
        self.R = torch.tensor(R_data)

        self.losses = []
        self.save = 2 #which file to save to

        self.alpha_tilda = torch.nn.Parameter(torch.rand(1,requires_grad=True))
        self.beta_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.sigma_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.lbda_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.rho_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        
        #find values for normalization
        self.S_max = max(self.S)
        self.V_max = max(self.V)
        self.I_max = max(self.I)
        self.D_max = max(self.D)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.V_min = min(self.V)
        self.I_min = min(self.I)
        self.D_min = min(self.D)
        self.R_min = min(self.R)

        #normalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.V_hat = (self.V - self.V_min) / (self.V_max - self.V_min)
        self.I_hat = (self.I - self.I_min) / (self.I_max - self.I_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)

        #matrices (x5 for S,V,I,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 5)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 5)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 5)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 5)); self.m4[:, 3] = 1
        self.m5 = torch.zeros((len(self.t), 5)); self.m5[:, 4] = 1

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha_tilda, self.beta_tilda, self.sigma_tilda, self.lbda_tilda, self.rho_tilda]))


    @property
    def alpha(self):
        return torch.tanh(self.alpha_tilda) * 3.5e-2

    @property
    def beta(self):
        return torch.tanh(self.beta_tilda) *0.5
    
    @property
    def sigma(self):
        return torch.tanh(self.sigma_tilda) *0.1

    @property
    def lbda(self):
        return torch.tanh(self.lbda_tilda) *0.002
    
    @property
    def rho(self):
        return torch.tanh(self.rho_tilda)*0.5

    #nets
    class Net_sidr(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()
            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
            self.fc5=nn.Linear(20, 20)
            self.fc6=nn.Linear(20, 20)
            self.fc7=nn.Linear(20, 20)
            self.fc8=nn.Linear(20, 20)
            self.out=nn.Linear(20, 5) #outputs S, V, I, D, R

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            sidr=F.relu(self.fc5(sidr))
            sidr=F.relu(self.fc6(sidr))
            sidr=F.relu(self.fc7(sidr))
            sidr=F.relu(self.fc8(sidr))
            sidr=self.out(sidr)
            return sidr
            
    def net_f(self, t_batch):
        sidr_hat = self.net_sidr(t_batch)

        S_hat, V_hat, I_hat, D_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3], sidr_hat[:,4]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #V_t
        sidr_hat.backward(self.m2, retain_graph=True)
        V_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_t
        sidr_hat.backward(self.m3, retain_graph=True)
        I_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #D_t
        sidr_hat.backward(self.m4, retain_graph=True)
        D_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m5, retain_graph=True)
        R_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        V = self.V_min + (self.V_max - self.V_min) * V_hat
        I = self.I_min + (self.I_max - self.I_min) * I_hat
        D = self.D_min + (self.D_max - self.D_min) * D_hat      
        R = self.R_min + (self.R_max - self.R_min) * R_hat

        f1_hat = S_hat_t - (-self.beta/self.N * S * I - self.alpha * S)  / (self.S_max - self.S_min)
        f2_hat = V_hat_t - (self.alpha * S - self.sigma * self.beta/self.N * V * I)  / (self.V_max - self.V_min)
        f3_hat = I_hat_t - (self.beta/self.N * S * I + self.sigma * self.beta/self.N * V * I - self.lbda * I - self.rho * I ) / (self.I_max - self.I_min)
        f4_hat = D_hat_t - (self.lbda * I) / (self.D_max - self.D_min)
        f5_hat = R_hat_t - (self.rho * I ) / (self.R_max - self.R_min)

        return f1_hat, f2_hat, f3_hat, f4_hat, f5_hat, S_hat, V_hat, I_hat, D_hat, R_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
        self.losses = checkpoint['losses']

      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S_pred_list = []
        V_pred_list = []
        I_pred_list = []
        D_pred_list = []
        R_pred_list = []

        f1, f2, f3, f4, f5, S_pred, V_pred, I_pred, D_pred, R_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred)
        V_pred_list.append(self.V_min + (self.V_max - self.V_min) * V_pred) 
        I_pred_list.append(self.I_min + (self.I_max - self.I_min) * I_pred)
        D_pred_list.append(self.D_min + (self.D_max - self.D_min) * D_pred)
        R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

        train_day = 90

        loss = (torch.mean(torch.square(self.S_hat[:train_day] - S_pred[:train_day]))+ 
                torch.mean(torch.square(self.V_hat[:train_day] - V_pred[:train_day]))+
                torch.mean(torch.square(self.I_hat[:train_day] - I_pred[:train_day]))+
                torch.mean(torch.square(self.D_hat[:train_day] - D_pred[:train_day]))+
                torch.mean(torch.square(self.R_hat[:train_day] - R_pred[:train_day]))+
                torch.mean(torch.square(f1[:train_day]))+
                torch.mean(torch.square(f2[:train_day]))+
                torch.mean(torch.square(f3[:train_day]))+
                torch.mean(torch.square(f4[:train_day]))+
                torch.mean(torch.square(f5[:train_day]))
                ) 

        #loss.backward(retain_graph=True)
        loss.backward()
        self.optimizer.step()
        self.scheduler.step() 
        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)
          print('alpha: (goal 3.5e-3 ', self.alpha)
          print('beta: (goal 0.3 ', self.beta)
          print('sigma: (goal 0.05 ', self.sigma)
          print('lbda: (goal 1e-3 ', self.lbda)
          print('rho: (goal 0.1 ', self.rho)
          print('#################################') 

        #loss + model parameters update
        if epoch % 4000 == 9999:
          #checkpoint save
          print('\nSaving model... Loss is: ', loss)
          torch.save({
              'epoch': epoch,
              'model': self.state_dict(),
              'optimizer_state_dict': self.optimizer.state_dict(),
              'scheduler': self.scheduler.state_dict(),
              #'loss': loss,
              'losses': self.losses,
              }, PATH + str(self.save)+'.pt')
          if self.save % 2 > 0: #its on 3
            self.save = 2 #change to 2
          else: #its on 2
            self.save = 3 #change to 3

      return S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list
# Out:
# Wall time: 1 ms

# %%
# %%time

dinn = DINN(sidr_data[0], sidr_data[1], sidr_data[2], sidr_data[3], 
            sidr_data[4], sidr_data[5]) #in the form of [t,S,V,I,D,R]

learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-6, max_lr=1e-3, step_size_up=1000, mode="exp_range", gamma=0.85, cycle_momentum=False)

dinn.scheduler = scheduler

nepochs = int(5e5)

# S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train

try: 
  S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
except EOFError:
  if dinn.save == 2:
    dinn.save = 3
    S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
  elif dinn.save == 3:
    dinn.save = 2
    S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
# Out:
# starting training...
#
#
# Epoch  0
# alpha: (goal 3.5e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1908], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0254], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0291], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  1000
# alpha: (goal 3.5e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1913], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0286], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  2000
# alpha: (goal 3.5e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1918], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0282], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  3000
# alpha: (goal 3.5e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1922], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0279], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  4000
# alpha: (goal 3.5e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1925], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0275], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  5000
# alpha: (goal 3.5e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1927], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0271], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  6000
# alpha: (goal 3.5e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1922], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0268], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  7000
# alpha: (goal 3.5e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1915], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0268], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  8000
# alpha: (goal 3.5e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1909], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0254], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0273], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  9000
# alpha: (goal 3.5e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1903], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0255], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0280], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  10000
# alpha: (goal 3.5e-3  tensor([0.0006], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1897], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0256], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0287], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  11000
# alpha: (goal 3.5e-3  tensor([0.0006], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1891], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0257], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0294], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  12000
# alpha: (goal 3.5e-3  tensor([0.0006], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1886], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0256], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0301], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  13000
# alpha: (goal 3.5e-3  tensor([0.0006], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1881], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0254], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0306], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  14000
# alpha: (goal 3.5e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1876], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0312], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  15000
# alpha: (goal 3.5e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1872], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0317], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  16000
# alpha: (goal 3.5e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1867], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0250], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0322], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  17000
# alpha: (goal 3.5e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1863], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0249], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0327], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  18000
# alpha: (goal 3.5e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1860], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0248], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0330], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  19000
# alpha: (goal 3.5e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1857], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0248], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0333], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  20000
# alpha: (goal 3.5e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1855], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0247], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0334], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  21000
# alpha: (goal 3.5e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1855], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0247], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0334], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  22000
# alpha: (goal 3.5e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1854], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0247], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0333], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  23000
# alpha: (goal 3.5e-3  tensor([0.0011], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1854], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0247], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0333], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  24000
# alpha: (goal 3.5e-3  tensor([0.0011], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1854], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0247], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0335], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  25000
# alpha: (goal 3.5e-3  tensor([0.0011], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1855], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0337], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  26000
# alpha: (goal 3.5e-3  tensor([0.0012], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1857], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0339], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  27000
# alpha: (goal 3.5e-3  tensor([0.0012], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1860], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0339], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  28000
# alpha: (goal 3.5e-3  tensor([0.0012], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1864], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0339], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  29000
# alpha: (goal 3.5e-3  tensor([0.0013], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1868], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0339], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  30000
# alpha: (goal 3.5e-3  tensor([0.0013], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1873], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0335], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  31000
# alpha: (goal 3.5e-3  tensor([0.0013], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1878], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0331], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  32000
# alpha: (goal 3.5e-3  tensor([0.0014], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1882], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0329], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  33000
# alpha: (goal 3.5e-3  tensor([0.0014], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1886], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0330], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  34000
# alpha: (goal 3.5e-3  tensor([0.0014], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1891], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0247], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0334], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  35000
# alpha: (goal 3.5e-3  tensor([0.0015], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1895], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0247], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0339], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  36000
# alpha: (goal 3.5e-3  tensor([0.0015], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1900], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0248], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0344], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  37000
# alpha: (goal 3.5e-3  tensor([0.0015], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1904], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0249], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0352], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  38000
# alpha: (goal 3.5e-3  tensor([0.0016], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1908], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0250], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0359], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  39000
# alpha: (goal 3.5e-3  tensor([0.0016], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1913], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0251], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0365], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  40000
# alpha: (goal 3.5e-3  tensor([0.0016], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1917], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0371], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  41000
# alpha: (goal 3.5e-3  tensor([0.0017], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1921], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0379], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  42000
# alpha: (goal 3.5e-3  tensor([0.0017], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1924], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0385], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  43000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1928], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0254], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0391], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  44000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1931], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0254], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0397], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  45000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1932], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0403], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  46000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1928], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0252], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0409], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  47000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1922], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0250], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0415], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  48000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1916], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0249], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0421], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  49000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1910], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0248], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0427], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  50000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1905], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0247], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0432], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  51000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1899], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0246], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0438], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  52000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1894], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0245], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0444], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  53000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1889], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0244], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0449], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  54000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1884], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0243], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0455], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  55000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1879], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0241], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0461], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  56000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1874], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0240], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0466], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  57000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1869], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0239], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0472], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  58000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1863], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0238], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0477], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  59000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1858], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0237], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0483], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  60000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1854], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0236], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0488], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  61000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1849], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0235], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0494], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  62000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1844], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0234], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0499], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  63000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1839], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0233], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0504], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  64000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1834], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0232], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0509], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  65000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1830], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0231], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0515], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  66000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1825], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0230], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0520], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  67000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1820], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0229], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0525], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  68000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1816], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0228], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0530], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  69000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1811], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0227], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0535], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  70000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1806], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0226], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0541], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  71000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1802], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0225], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0546], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  72000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1797], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0224], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0551], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  73000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1792], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0223], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0556], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  74000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1788], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0222], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0561], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  75000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1783], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0221], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0566], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  76000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1778], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0220], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0572], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  77000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1774], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0219], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0577], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  78000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1769], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0218], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0582], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  79000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1765], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0217], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0587], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  80000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1760], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0216], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0592], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  81000
# alpha: (goal 3.5e-3  tensor([0.0017], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1756], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0215], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0597], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  82000
# alpha: (goal 3.5e-3  tensor([0.0017], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1751], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0214], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0602], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  83000
# alpha: (goal 3.5e-3  tensor([0.0017], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1747], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0213], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0607], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  84000
# alpha: (goal 3.5e-3  tensor([0.0017], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1742], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0212], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0612], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  85000
# alpha: (goal 3.5e-3  tensor([0.0017], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1738], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0211], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0617], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  86000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1733], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0211], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0621], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  87000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1729], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0210], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0626], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  88000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1725], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0209], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0631], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  89000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1720], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0208], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0636], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  90000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1716], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0207], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0641], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  91000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1712], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0206], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0645], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  92000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1707], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0205], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0650], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  93000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1703], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0204], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0655], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  94000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1698], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0203], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0660], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  95000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1694], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0202], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0664], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  96000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1690], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0201], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0669], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  97000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1686], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0201], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0674], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  98000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1681], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0200], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0679], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  99000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1677], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0199], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0683], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  100000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1673], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0198], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0688], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  101000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1669], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0197], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0692], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  102000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1664], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0196], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0697], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  103000
# alpha: (goal 3.5e-3  tensor([0.0024], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1660], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0196], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0701], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  104000
# alpha: (goal 3.5e-3  tensor([0.0024], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1656], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0195], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0706], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  105000
# alpha: (goal 3.5e-3  tensor([0.0024], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1652], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0194], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0710], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  106000
# alpha: (goal 3.5e-3  tensor([0.0025], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1648], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0193], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0715], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  107000
# alpha: (goal 3.5e-3  tensor([0.0025], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1643], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0192], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0719], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  108000
# alpha: (goal 3.5e-3  tensor([0.0026], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1639], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0192], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0723], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  109000
# alpha: (goal 3.5e-3  tensor([0.0026], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1635], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0191], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0727], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  110000
# alpha: (goal 3.5e-3  tensor([0.0026], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1631], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0192], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0731], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  111000
# alpha: (goal 3.5e-3  tensor([0.0026], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1627], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0193], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0734], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  112000
# alpha: (goal 3.5e-3  tensor([0.0027], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1624], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0194], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0737], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  113000
# alpha: (goal 3.5e-3  tensor([0.0027], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1620], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0196], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0738], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  114000
# alpha: (goal 3.5e-3  tensor([0.0027], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1616], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0197], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0735], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  115000
# alpha: (goal 3.5e-3  tensor([0.0028], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1612], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0198], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0730], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  116000
# alpha: (goal 3.5e-3  tensor([0.0028], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1608], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0199], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0724], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  117000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1604], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0200], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0718], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  118000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1600], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0201], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0712], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  119000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1596], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0202], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0707], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  120000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1592], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0203], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0701], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  121000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1589], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0204], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0696], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  122000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1585], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0205], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0691], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  123000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1581], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0206], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0686], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  124000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1577], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0207], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0680], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  125000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1573], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0208], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0676], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  126000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1569], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0209], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0671], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  127000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1565], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0210], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0666], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  128000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1561], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0211], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0661], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  129000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1556], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0211], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0657], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  130000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1551], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0212], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0652], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  131000
# alpha: (goal 3.5e-3  tensor([0.0033], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1547], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0213], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0648], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  132000
# alpha: (goal 3.5e-3  tensor([0.0033], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1542], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0214], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0644], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  133000
# alpha: (goal 3.5e-3  tensor([0.0033], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1537], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0215], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0640], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  134000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1532], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0216], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0636], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  135000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1528], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0217], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0633], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  136000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1523], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0218], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0629], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  137000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1519], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0219], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0625], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  138000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1514], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0220], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0621], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  139000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1510], grad_fn=<MulBackward0>)
# ...
# rho: (goal 0.1  tensor([0.0905], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  454000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2724], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0485], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0906], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  455000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2727], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0485], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0907], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  456000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2731], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0486], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0908], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  457000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2735], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0487], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0910], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  458000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2738], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0488], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0911], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  459000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2742], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0488], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0912], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  460000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2745], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0489], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0913], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  461000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2749], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0490], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0914], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  462000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2752], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0491], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0916], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  463000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2756], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0491], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0917], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  464000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2759], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0492], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0918], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  465000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2763], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0493], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0919], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  466000
# alpha: (goal 3.5e-3  tensor([0.0032], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2766], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0493], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0920], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  467000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2770], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0494], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0922], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  468000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2773], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0495], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0923], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  469000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2776], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0495], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0924], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  470000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2780], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0496], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0925], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  471000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2783], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0497], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0926], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  472000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2786], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0498], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0927], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  473000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2790], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0498], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0928], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  474000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2793], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0499], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0929], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  475000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2796], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0500], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0931], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  476000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2800], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0500], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0932], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  477000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2803], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0501], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0933], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  478000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2806], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0502], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0934], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  479000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2809], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0502], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0935], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  480000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2813], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0503], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0936], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  481000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2816], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0504], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0937], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  482000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2819], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0504], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0938], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  483000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2822], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0505], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0940], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  484000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2826], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0506], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0941], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  485000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2829], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0506], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0942], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  486000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2832], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0507], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0943], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  487000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2835], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0507], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0944], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  488000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2839], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0508], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0945], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  489000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2842], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0509], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0946], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  490000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2845], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0509], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0947], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  491000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2848], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0510], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0948], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  492000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2852], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0511], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0949], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  493000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2855], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0511], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0951], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  494000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2858], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0512], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0952], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  495000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2861], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0512], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0953], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  496000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2865], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0513], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0955], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  497000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2868], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0513], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0956], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  498000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2871], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0514], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0957], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  499000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2874], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0514], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.0958], grad_fn=<MulBackward0>)
# #################################
# Wall time: 50min 26s

# %%
plt.plot(dinn.losses, color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss'),
# Out:
# (Text(0, 0.5, 'Loss'),)

# %%
fig = plt.figure(figsize=(12,12))

ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')



ax.scatter(sidr_data[0], sidr_data[1], color = 'darkgreen', label='Susceptible Data', s=15)
ax.plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[2], color = 'blue', label='Vaccinated Data', s=15)
ax.plot(sidr_data[0], V_pred_list[0].detach().numpy(), 'lightblue', alpha=0.9, lw=2, label='Vaccinated Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[3], color = 'red', label='Infected Data', s=15)
ax.plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'pink', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[4], color = 'black', label='Dead Data', s=15)
ax.plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'grey', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[5], color = 'green', label='Recovered Data', s=15)
ax.plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'lightgreen', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')


ax.set_xlabel('Time /days',size = 20)
ax.set_ylabel('Number',size = 20)

ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
plt.xticks(size = 20)
plt.yticks(size = 20)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend(prop={'size':20})
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('covid_missing_I.pdf')
plt.show()

# %%
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

fig, ax = plt.subplots(2, 3, figsize = (12,12))

for i in range(2):
    for j in range(3):
        ax[i, j].set_facecolor('xkcd:white')


train_day = 90

ax[0, 0].scatter(sidr_data[0][:train_day], sidr_data[1][:train_day], c = 'black', alpha=0.5, lw=2, label='Susceptible Data')
ax[0, 0].scatter(sidr_data[0][train_day:], sidr_data[1][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 0].plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax[0, 1].scatter(sidr_data[0][:train_day], sidr_data[2][:train_day], c = 'black', alpha=0.5, lw=2, label='Vaccinated Data')
ax[0, 1].scatter(sidr_data[0][train_day:], sidr_data[2][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 1].plot(sidr_data[0], V_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Vaccinated Prediction', linestyle='dashed')

ax[0, 2].scatter(sidr_data[0][:train_day], sidr_data[3][:train_day], c = 'violet', alpha=0.5, lw=2, label='Infected Data')
ax[0, 2].scatter(sidr_data[0][train_day:], sidr_data[3][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 2].plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'black', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

ax[1, 0].scatter(sidr_data[0][:train_day], sidr_data[4][:train_day], c = 'black', alpha=0.5, lw=2, label='Dead Data')
ax[1, 0].scatter(sidr_data[0][train_day:], sidr_data[4][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 0].plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax[1, 1].scatter(sidr_data[0][:train_day], sidr_data[5][:train_day], c = 'blue', alpha=0.5, lw=2, label='Recovered Data')
ax[1, 1].scatter(sidr_data[0][train_day:], sidr_data[5][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 1].plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')

for i in range(2):
    for j in range(3):
        ax[i, j].set_xlabel('Time /days',size = 20)
        ax[i, j].set_ylabel('Number',size = 20)
        ax[i, j].yaxis.set_tick_params(length=0)
        ax[i, j].xaxis.set_tick_params(length=0)
        legend = ax[i, j].legend(prop={'size':18})
        legend.get_frame().set_alpha(0.5)
        for spine in ('top', 'right', 'bottom', 'left'):
            ax[i, j].spines[spine].set_visible(False)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initial conditions
N = 3e8

S0 = N - 1
V0 = 0
I0 = 1
D0 = 0
R0 = 0
# A grid of time points (in days)
t = np.linspace(0, 500, 100) 

#parameters
alpha = dinn.alpha.detach().numpy().item()
beta = dinn.beta.detach().numpy().item()
sigma = dinn.sigma.detach().numpy().item()
lbda = dinn.lbda.detach().numpy().item()
rho = dinn.rho.detach().numpy().item()
print('alpha: (goal 3.5e-3 ', alpha)
print('beta: (goal 0.3 ', beta)
print('sigma: (goal 0.05 ', sigma)
print('lbda: (goal 1e-3 ', lbda)
print('rho: (goal 0.1 ', rho)
print('#################################')

# The SIR model differential equations.
def deriv(y, t, alpha, beta, sigma, lbda, rho):
    S, V, I, D, R = y
    dSdt = - beta/N * S * I - alpha * S
    dVdt = alpha * S - sigma * beta/N * V * I
    dIdt = beta/N * S * I + sigma * beta/N * V * I - lbda * I - rho * I 
    dDdt = lbda * I
    dRdt = rho * I

    return dSdt, dVdt, dIdt, dDdt, dRdt


# Initial conditions vector
y0 = S0, V0, I0, D0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(alpha, beta, sigma, lbda, rho))
S, V, I, D, R = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w', figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, S, 'purple', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
# ax.plot(t, sidr_data[1], 'violet', alpha=0.5, lw=2, label='Susceptible')

ax.plot(t, V, 'blue', alpha=0.5, lw=2, label='Learnable Param Vaccinated', linestyle='dashed')
ax.plot(t, sidr_data[2], 'dodgerblue', alpha=0.5, lw=2, label='Vaccinated')

ax.plot(t, I, 'red', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.plot(t, sidr_data[3], 'pink', alpha=0.5, lw=2, label='Infected')

ax.plot(t, D, 'black', alpha=0.5, lw=2, label='Learnable Param Dead', linestyle='dashed')
ax.plot(t, sidr_data[4], 'grey', alpha=0.5, lw=2, label='Dead')

ax.plot(t, R, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Recovered', linestyle='dashed')
# ax.plot(t, sidr_data[5], 'green', alpha=0.5, lw=2, label='Recovered')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()
# Out:
# alpha: (goal 3.5e-3  0.003142928471788764
# beta: (goal 0.3  0.28775835037231445
# sigma: (goal 0.05  0.0514741912484169
# lbda: (goal 1e-3  0.001013144850730896
# rho: (goal 0.1  0.09594309329986572
# #################################
