# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

sidr_data = genfromtxt('island_40weeks.csv', delimiter=',') #in the form of [t,S,I,D,R]

torch.manual_seed(1234)

# %%
# %%time

PATH = 'sidr_norm_simple' 

class DINN(nn.Module):
    def __init__(self, t, S_data, I_data, D_data, R_data): #[t,S,I,D,R]
        super(DINN, self).__init__()
        self.N = 12111 #population size
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S = torch.tensor(S_data)
        self.I = torch.tensor(I_data)
        self.D = torch.tensor(D_data)
        self.R = torch.tensor(R_data)

        self.losses = []
        self.save = 2 #which file to save to

        self.alpha_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.beta_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.gamma_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        
        #find values for normalization
        self.S_max = max(self.S)
        self.I_max = max(self.I)
        self.D_max = max(self.D)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.I_min = min(self.I)
        self.D_min = min(self.D)
        self.R_min = min(self.R)

        #normalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.I_hat = (self.I - self.I_min) / (self.I_max - self.I_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)

        #matrices (x4 for S,I,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 4)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 4)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 4)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 4)); self.m4[:, 3] = 1

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha_tilda, self.beta_tilda, self.gamma_tilda]))

    @property
    def alpha(self):
        return self.alpha_tilda

    @property
    def beta(self):
        return self.beta_tilda

    @property
    def gamma(self):
        return self.gamma_tilda


    #nets
    class Net_sidr(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()
            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
            self.fc5=nn.Linear(20, 20)
            self.fc6=nn.Linear(20, 20)
            self.fc7=nn.Linear(20, 20)
            self.fc8=nn.Linear(20, 20)
            self.out=nn.Linear(20, 4) #outputs S, I, D, R

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            sidr=F.relu(self.fc5(sidr))
            sidr=F.relu(self.fc6(sidr))
            sidr=F.relu(self.fc7(sidr))
            sidr=F.relu(self.fc8(sidr))
            sidr=self.out(sidr)
            return sidr
            
    def net_f(self, t_batch):
        sidr_hat = self.net_sidr(t_batch)

        S_hat, I_hat, D_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_t
        sidr_hat.backward(self.m2, retain_graph=True)
        I_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #D_t
        sidr_hat.backward(self.m3, retain_graph=True)
        D_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m4, retain_graph=True)
        R_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        I = self.I_min + (self.I_max - self.I_min) * I_hat
        D = self.D_min + (self.D_max - self.D_min) * D_hat      
        R = self.R_min + (self.R_max - self.R_min) * R_hat

        f1_hat = S_hat_t - (-(self.alpha / self.N) * S * I)  / (self.S_max - self.S_min)
        f2_hat = I_hat_t - ((self.alpha / self.N) * S * I - self.beta * I - self.gamma * I ) / (self.I_max - self.I_min)
        f3_hat = D_hat_t - (self.gamma * I) / (self.D_max - self.D_min)
        f4_hat = R_hat_t - (self.beta * I ) / (self.R_max - self.R_min)

        return f1_hat, f2_hat, f3_hat, f4_hat, S_hat, I_hat, D_hat, R_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
        self.losses = checkpoint['losses']

      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S_pred_list = []
        I_pred_list = []
        D_pred_list = []
        R_pred_list = []

        f1, f2, f3, f4, S_pred, I_pred, D_pred, R_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred) 
        I_pred_list.append(self.I_min + (self.I_max - self.I_min) * I_pred)
        D_pred_list.append(self.D_min + (self.D_max - self.D_min) * D_pred)
        R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

        train_day = 35

        loss = (torch.mean(torch.square(self.S_hat[:train_day] - S_pred[:train_day]))+ 
                torch.mean(torch.square(self.I_hat[:train_day] - I_pred[:train_day]))+
                torch.mean(torch.square(self.D_hat[:train_day] - D_pred[:train_day]))+
                torch.mean(torch.square(self.R_hat[:train_day] - R_pred[:train_day]))+
                torch.mean(torch.square(f1[:train_day]))+
                torch.mean(torch.square(f2[:train_day]))+
                torch.mean(torch.square(f3[:train_day]))+
                torch.mean(torch.square(f4[:train_day]))
                ) 

        #loss.backward(retain_graph=True)
        loss.backward()
        self.optimizer.step()
        self.scheduler.step() 
        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)

          print('alpha: ', self.alpha)
          print('beta:', self.beta)
          print('gamma: ', self.gamma)

          print('#################################')                

      return S_pred_list, I_pred_list, D_pred_list, R_pred_list
# Out:
# Wall time: 0 ns

# %%
# %%time

dinn = DINN(sidr_data[0], sidr_data[1], sidr_data[2], sidr_data[4], 
            sidr_data[3]) #in the form of [t,S,I,D,R]

learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-6, max_lr=1e-3, step_size_up=5, mode="exp_range", cycle_momentum=False)

dinn.scheduler = scheduler

nepochs = int(1e5)

# S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train

try: 
  S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
except EOFError:
  if dinn.save == 2:
    dinn.save = 3
    S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
  elif dinn.save == 3:
    dinn.save = 2
    S_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
# Out:
# starting training...
#
#
# Epoch  0
# alpha:  Parameter containing:
# tensor([0.0290], requires_grad=True)
# beta: Parameter containing:
# tensor([0.4019], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2598], requires_grad=True)
# #################################
#
# Epoch  1000
# alpha:  Parameter containing:
# tensor([0.0447], requires_grad=True)
# beta: Parameter containing:
# tensor([0.3923], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2503], requires_grad=True)
# #################################
#
# Epoch  2000
# alpha:  Parameter containing:
# tensor([0.0447], requires_grad=True)
# beta: Parameter containing:
# tensor([0.3923], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2503], requires_grad=True)
# #################################
#
# Epoch  3000
# alpha:  Parameter containing:
# tensor([0.0447], requires_grad=True)
# beta: Parameter containing:
# tensor([0.3924], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2503], requires_grad=True)
# #################################
#
# Epoch  4000
# alpha:  Parameter containing:
# tensor([0.0448], requires_grad=True)
# beta: Parameter containing:
# tensor([0.3931], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2502], requires_grad=True)
# #################################
#
# Epoch  5000
# alpha:  Parameter containing:
# tensor([0.0457], requires_grad=True)
# beta: Parameter containing:
# tensor([0.3982], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2497], requires_grad=True)
# #################################
#
# Epoch  6000
# alpha:  Parameter containing:
# tensor([0.0472], requires_grad=True)
# beta: Parameter containing:
# tensor([0.4050], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2482], requires_grad=True)
# #################################
#
# Epoch  7000
# alpha:  Parameter containing:
# tensor([0.0491], requires_grad=True)
# beta: Parameter containing:
# tensor([0.4129], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2455], requires_grad=True)
# #################################
#
# Epoch  8000
# alpha:  Parameter containing:
# tensor([0.0422], requires_grad=True)
# beta: Parameter containing:
# tensor([0.4044], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2391], requires_grad=True)
# #################################
#
# Epoch  9000
# alpha:  Parameter containing:
# tensor([0.0698], requires_grad=True)
# beta: Parameter containing:
# tensor([0.4912], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2346], requires_grad=True)
# #################################
#
# Epoch  10000
# alpha:  Parameter containing:
# tensor([0.0670], requires_grad=True)
# beta: Parameter containing:
# tensor([0.4793], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2239], requires_grad=True)
# #################################
#
# Epoch  11000
# alpha:  Parameter containing:
# tensor([0.0885], requires_grad=True)
# beta: Parameter containing:
# tensor([0.4914], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.2139], requires_grad=True)
# #################################
#
# Epoch  12000
# alpha:  Parameter containing:
# tensor([0.3152], requires_grad=True)
# beta: Parameter containing:
# tensor([0.6944], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.1918], requires_grad=True)
# #################################
#
# Epoch  13000
# alpha:  Parameter containing:
# tensor([0.5113], requires_grad=True)
# beta: Parameter containing:
# tensor([0.8425], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.1755], requires_grad=True)
# #################################
#
# Epoch  14000
# alpha:  Parameter containing:
# tensor([0.2656], requires_grad=True)
# beta: Parameter containing:
# tensor([0.5430], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.1577], requires_grad=True)
# #################################
#
# Epoch  15000
# alpha:  Parameter containing:
# tensor([-0.0881], requires_grad=True)
# beta: Parameter containing:
# tensor([0.1506], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.1305], requires_grad=True)
# #################################
#
# Epoch  16000
# alpha:  Parameter containing:
# tensor([-0.5381], requires_grad=True)
# beta: Parameter containing:
# tensor([-0.3176], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.1116], requires_grad=True)
# #################################
#
# Epoch  17000
# alpha:  Parameter containing:
# tensor([-1.0472], requires_grad=True)
# beta: Parameter containing:
# tensor([-0.8310], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0879], requires_grad=True)
# #################################
#
# Epoch  18000
# alpha:  Parameter containing:
# tensor([-1.5121], requires_grad=True)
# beta: Parameter containing:
# tensor([-1.2946], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0708], requires_grad=True)
# #################################
#
# Epoch  19000
# alpha:  Parameter containing:
# tensor([-2.0419], requires_grad=True)
# beta: Parameter containing:
# tensor([-1.8234], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0522], requires_grad=True)
# #################################
#
# Epoch  20000
# alpha:  Parameter containing:
# tensor([-2.6892], requires_grad=True)
# beta: Parameter containing:
# tensor([-2.4686], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0171], requires_grad=True)
# #################################
#
# Epoch  21000
# alpha:  Parameter containing:
# tensor([-3.3860], requires_grad=True)
# beta: Parameter containing:
# tensor([-2.9565], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0102], requires_grad=True)
# #################################
#
# Epoch  22000
# alpha:  Parameter containing:
# tensor([-3.2885], requires_grad=True)
# beta: Parameter containing:
# tensor([-2.6534], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0041], requires_grad=True)
# #################################
#
# Epoch  23000
# alpha:  Parameter containing:
# tensor([-3.3890], requires_grad=True)
# beta: Parameter containing:
# tensor([-2.8215], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0048], requires_grad=True)
# #################################
#
# Epoch  24000
# alpha:  Parameter containing:
# tensor([-2.9786], requires_grad=True)
# beta: Parameter containing:
# tensor([-2.6140], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0181], requires_grad=True)
# #################################
#
# Epoch  25000
# alpha:  Parameter containing:
# tensor([-2.6457], requires_grad=True)
# beta: Parameter containing:
# tensor([-2.4365], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0209], requires_grad=True)
# #################################
#
# Epoch  26000
# alpha:  Parameter containing:
# tensor([-2.2539], requires_grad=True)
# beta: Parameter containing:
# tensor([-2.1845], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0186], requires_grad=True)
# #################################
#
# Epoch  27000
# alpha:  Parameter containing:
# tensor([-1.8039], requires_grad=True)
# beta: Parameter containing:
# tensor([-1.8306], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0185], requires_grad=True)
# #################################
#
# Epoch  28000
# alpha:  Parameter containing:
# tensor([-1.2685], requires_grad=True)
# beta: Parameter containing:
# tensor([-1.3268], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0101], requires_grad=True)
# #################################
#
# Epoch  29000
# alpha:  Parameter containing:
# tensor([-0.6820], requires_grad=True)
# beta: Parameter containing:
# tensor([-0.7104], requires_grad=True)
# gamma:  Parameter containing:
# tensor([0.0068], requires_grad=True)
# #################################
#
# Epoch  30000
# alpha:  Parameter containing:
# tensor([0.1859], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0484], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.4563e-05], requires_grad=True)
# #################################
#
# Epoch  31000
# alpha:  Parameter containing:
# tensor([0.1859], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0488], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8885e-05], requires_grad=True)
# #################################
#
# Epoch  32000
# alpha:  Parameter containing:
# tensor([0.1801], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0470], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9373e-05], requires_grad=True)
# #################################
#
# Epoch  33000
# alpha:  Parameter containing:
# tensor([0.1802], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0474], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8899e-05], requires_grad=True)
# #################################
#
# Epoch  34000
# alpha:  Parameter containing:
# tensor([0.1799], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0476], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9446e-05], requires_grad=True)
# #################################
#
# Epoch  35000
# alpha:  Parameter containing:
# tensor([0.1786], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0473], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9482e-05], requires_grad=True)
# #################################
#
# Epoch  36000
# alpha:  Parameter containing:
# tensor([0.1791], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0476], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9202e-05], requires_grad=True)
# #################################
#
# Epoch  37000
# alpha:  Parameter containing:
# tensor([0.1803], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0459], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.3906e-05], requires_grad=True)
# #################################
#
# Epoch  38000
# alpha:  Parameter containing:
# tensor([0.1805], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0481], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9192e-05], requires_grad=True)
# #################################
#
# Epoch  39000
# alpha:  Parameter containing:
# tensor([0.1799], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0479], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8955e-05], requires_grad=True)
# #################################
#
# Epoch  40000
# alpha:  Parameter containing:
# tensor([0.1794], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0486], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8807e-05], requires_grad=True)
# #################################
#
# Epoch  41000
# alpha:  Parameter containing:
# tensor([0.1774], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0470], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8904e-05], requires_grad=True)
# #################################
#
# Epoch  42000
# alpha:  Parameter containing:
# tensor([0.1811], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0479], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8591e-05], requires_grad=True)
# #################################
#
# Epoch  43000
# alpha:  Parameter containing:
# tensor([0.1798], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0478], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8589e-05], requires_grad=True)
# #################################
#
# Epoch  44000
# alpha:  Parameter containing:
# tensor([0.1777], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0480], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8306e-05], requires_grad=True)
# #################################
#
# Epoch  45000
# alpha:  Parameter containing:
# tensor([0.1773], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0474], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8659e-05], requires_grad=True)
# #################################
#
# Epoch  46000
# alpha:  Parameter containing:
# tensor([0.1772], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0467], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8473e-05], requires_grad=True)
# #################################
#
# Epoch  47000
# alpha:  Parameter containing:
# tensor([0.1771], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0471], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9273e-05], requires_grad=True)
# #################################
#
# Epoch  48000
# alpha:  Parameter containing:
# tensor([0.1734], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0468], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9499e-05], requires_grad=True)
# #################################
#
# Epoch  49000
# alpha:  Parameter containing:
# tensor([0.1778], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0484], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8139e-05], requires_grad=True)
# #################################
#
# Epoch  50000
# alpha:  Parameter containing:
# tensor([0.1762], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0480], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9278e-05], requires_grad=True)
# #################################
#
# Epoch  51000
# alpha:  Parameter containing:
# tensor([0.1774], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0463], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9102e-05], requires_grad=True)
# #################################
#
# Epoch  52000
# alpha:  Parameter containing:
# tensor([0.1738], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0475], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9301e-05], requires_grad=True)
# #################################
#
# Epoch  53000
# alpha:  Parameter containing:
# tensor([0.1754], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0463], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9572e-05], requires_grad=True)
# #################################
#
# Epoch  54000
# alpha:  Parameter containing:
# tensor([0.1752], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0465], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8765e-05], requires_grad=True)
# #################################
#
# Epoch  55000
# alpha:  Parameter containing:
# tensor([0.1730], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0463], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.7275e-05], requires_grad=True)
# #################################
#
# Epoch  56000
# alpha:  Parameter containing:
# tensor([0.1754], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0461], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8882e-05], requires_grad=True)
# #################################
#
# Epoch  57000
# alpha:  Parameter containing:
# tensor([0.1752], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0466], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9010e-05], requires_grad=True)
# #################################
#
# Epoch  58000
# alpha:  Parameter containing:
# tensor([0.1732], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0455], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8255e-05], requires_grad=True)
# #################################
#
# Epoch  59000
# alpha:  Parameter containing:
# tensor([0.1752], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0466], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8281e-05], requires_grad=True)
# #################################
#
# Epoch  60000
# alpha:  Parameter containing:
# tensor([0.1758], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0465], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8510e-05], requires_grad=True)
# #################################
#
# Epoch  61000
# alpha:  Parameter containing:
# tensor([0.1756], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0465], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-2.0787e-05], requires_grad=True)
# #################################
#
# Epoch  62000
# alpha:  Parameter containing:
# tensor([0.1748], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0472], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.7075e-05], requires_grad=True)
# #################################
#
# Epoch  63000
# alpha:  Parameter containing:
# tensor([0.1748], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0464], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8435e-05], requires_grad=True)
# #################################
#
# Epoch  64000
# alpha:  Parameter containing:
# tensor([0.1752], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0463], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8780e-05], requires_grad=True)
# #################################
#
# Epoch  65000
# alpha:  Parameter containing:
# tensor([0.1768], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0482], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9501e-05], requires_grad=True)
# #################################
#
# Epoch  66000
# alpha:  Parameter containing:
# tensor([0.1745], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0459], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8586e-05], requires_grad=True)
# #################################
#
# Epoch  67000
# alpha:  Parameter containing:
# tensor([0.1753], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0460], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9222e-05], requires_grad=True)
# #################################
#
# Epoch  68000
# alpha:  Parameter containing:
# tensor([0.1745], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0460], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8474e-05], requires_grad=True)
# #################################
#
# Epoch  69000
# alpha:  Parameter containing:
# tensor([0.1746], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0454], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9984e-05], requires_grad=True)
# #################################
#
# Epoch  70000
# alpha:  Parameter containing:
# tensor([0.1754], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0474], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-2.1006e-05], requires_grad=True)
# #################################
#
# Epoch  71000
# alpha:  Parameter containing:
# tensor([0.1735], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0473], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8739e-05], requires_grad=True)
# #################################
#
# Epoch  72000
# alpha:  Parameter containing:
# tensor([0.1732], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0472], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8079e-05], requires_grad=True)
# #################################
#
# Epoch  73000
# alpha:  Parameter containing:
# tensor([0.1741], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0475], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9427e-05], requires_grad=True)
# #################################
#
# Epoch  74000
# alpha:  Parameter containing:
# tensor([0.1726], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0459], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8513e-05], requires_grad=True)
# #################################
#
# Epoch  75000
# alpha:  Parameter containing:
# tensor([0.1753], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0477], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8390e-05], requires_grad=True)
# #################################
#
# Epoch  76000
# alpha:  Parameter containing:
# tensor([0.1762], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0469], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8335e-05], requires_grad=True)
# #################################
#
# Epoch  77000
# alpha:  Parameter containing:
# tensor([0.1735], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0475], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9786e-05], requires_grad=True)
# #################################
#
# Epoch  78000
# alpha:  Parameter containing:
# tensor([0.1737], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0479], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-2.0129e-05], requires_grad=True)
# #################################
#
# Epoch  79000
# alpha:  Parameter containing:
# tensor([0.1735], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0469], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9251e-05], requires_grad=True)
# #################################
#
# Epoch  80000
# alpha:  Parameter containing:
# tensor([0.1726], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0458], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8456e-05], requires_grad=True)
# #################################
#
# Epoch  81000
# alpha:  Parameter containing:
# tensor([0.1741], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0473], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.7958e-05], requires_grad=True)
# #################################
#
# Epoch  82000
# alpha:  Parameter containing:
# tensor([0.1721], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0465], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8588e-05], requires_grad=True)
# #################################
#
# Epoch  83000
# alpha:  Parameter containing:
# tensor([0.1732], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0475], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-2.0237e-05], requires_grad=True)
# #################################
#
# Epoch  84000
# alpha:  Parameter containing:
# tensor([0.1720], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0466], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.7264e-05], requires_grad=True)
# #################################
#
# Epoch  85000
# alpha:  Parameter containing:
# tensor([0.1723], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0454], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8766e-05], requires_grad=True)
# #################################
#
# Epoch  86000
# alpha:  Parameter containing:
# tensor([0.1725], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0451], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9076e-05], requires_grad=True)
# #################################
#
# Epoch  87000
# alpha:  Parameter containing:
# tensor([0.1716], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0463], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8935e-05], requires_grad=True)
# #################################
#
# Epoch  88000
# alpha:  Parameter containing:
# tensor([0.1696], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0443], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9290e-05], requires_grad=True)
# #################################
#
# Epoch  89000
# alpha:  Parameter containing:
# tensor([0.1690], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0449], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8980e-05], requires_grad=True)
# #################################
#
# Epoch  90000
# alpha:  Parameter containing:
# tensor([0.1685], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0453], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9054e-05], requires_grad=True)
# #################################
#
# Epoch  91000
# alpha:  Parameter containing:
# tensor([0.1692], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0449], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9439e-05], requires_grad=True)
# #################################
#
# Epoch  92000
# alpha:  Parameter containing:
# tensor([0.1684], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0445], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9678e-05], requires_grad=True)
# #################################
#
# Epoch  93000
# alpha:  Parameter containing:
# tensor([0.1687], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0445], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9113e-05], requires_grad=True)
# #################################
#
# Epoch  94000
# alpha:  Parameter containing:
# tensor([0.1689], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0456], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9097e-05], requires_grad=True)
# #################################
#
# Epoch  95000
# alpha:  Parameter containing:
# tensor([0.1686], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0445], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9130e-05], requires_grad=True)
# #################################
#
# Epoch  96000
# alpha:  Parameter containing:
# tensor([0.1691], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0462], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8867e-05], requires_grad=True)
# #################################
#
# Epoch  97000
# alpha:  Parameter containing:
# tensor([0.1683], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0446], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.8814e-05], requires_grad=True)
# #################################
#
# Epoch  98000
# alpha:  Parameter containing:
# tensor([0.1694], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0443], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9198e-05], requires_grad=True)
# #################################
#
# Epoch  99000
# alpha:  Parameter containing:
# tensor([0.1693], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0443], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9269e-05], requires_grad=True)
# #################################
# Wall time: 10min 14s

# %%
plt.plot(dinn.losses, color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss')
print('total loss', dinn.losses[-1])
print('alpha: ', dinn.alpha)
print('beta:', dinn.beta)
print('gamma: ', dinn.gamma)
# Out:
# total loss 0.0026356058795110092
# alpha:  Parameter containing:
# tensor([0.1691], requires_grad=True)
# beta: Parameter containing:
# tensor([0.0450], requires_grad=True)
# gamma:  Parameter containing:
# tensor([-1.9117e-05], requires_grad=True)

# %%
fig = plt.figure(figsize=(20,20))

ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')


ax.scatter(sidr_data[0], sidr_data[1], color = 'red', label='Susceptible Data', s=15)
ax.plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'pink', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax.scatter(sidr_data[0], sidr_data[2], color = 'violet', label='Infected Data', s=15)
ax.plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'dodgerblue', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

ax.scatter(sidr_data[0], sidr_data[4], color = 'black', label='Dead Data', s=15)
ax.plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax.scatter(sidr_data[0], sidr_data[3], color = 'darkorchid', label='Recovered Data', s=15)
ax.plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')


ax.set_xlabel('Time /weeks',size = 10)
ax.set_ylabel('Number',size = 20)
#ax.set_ylim([-1,50])
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
plt.xticks(size = 10)
plt.yticks(size = 20)
# ax.grid(b=True, which='major', c='black', lw=2.2, ls=15-')
legend = ax.legend(prop={'size':20})
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('output_1')
plt.show()

# %%
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

fig, ax = plt.subplots(2, 2, figsize = (12,12))

for i in range(2):
    for j in range(2):
        ax[i, j].set_facecolor('xkcd:white')


train_day = 35

ax[0, 0].scatter(sidr_data[0][:train_day], sidr_data[1][:train_day], c = 'black', alpha=0.5, lw=2, label='Susceptible Data')
ax[0, 0].scatter(sidr_data[0][train_day:], sidr_data[1][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 0].plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax[0, 1].scatter(sidr_data[0][:train_day], sidr_data[2][:train_day], c = 'violet', alpha=0.5, lw=2, label='Infected Data')
ax[0, 1].scatter(sidr_data[0][train_day:], sidr_data[2][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 1].plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'black', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

ax[1, 0].scatter(sidr_data[0][:train_day], sidr_data[4][:train_day], c = 'black', alpha=0.5, lw=2, label='Dead Data')
ax[1, 0].scatter(sidr_data[0][train_day:], sidr_data[4][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 0].plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax[1, 1].scatter(sidr_data[0][:train_day], sidr_data[3][:train_day], c = 'blue', alpha=0.5, lw=2, label='Recovered Data')
ax[1, 1].scatter(sidr_data[0][train_day:], sidr_data[3][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 1].plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')

for i in range(2):
    for j in range(2):
        ax[i, j].set_xlabel('Time /days',size = 20)
        ax[i, j].set_ylabel('Number',size = 20)
        ax[i, j].yaxis.set_tick_params(length=0)
        ax[i, j].xaxis.set_tick_params(length=0)
        legend = ax[i, j].legend(prop={'size':18})
        legend.get_frame().set_alpha(0.5)
        for spine in ('top', 'right', 'bottom', 'left'):
            ax[i, j].spines[spine].set_visible(False)
plt.savefig('output_1_2')
plt.show()
