# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

sidr_data = genfromtxt('svidr_sim.csv', delimiter=',') #in the form of [t,S,V,I,D,R]

torch.manual_seed(1234)

# %%
sidr_data.shape
# Out:
# (6, 100)

# %%
# %%time

PATH = 'svidr_norm_simple' 

class DINN(nn.Module):
    def __init__(self, t, S_data, V_data, I_data, D_data, R_data): #[t,S,V,I,D,R]
        super(DINN, self).__init__()
        self.N = 3e8 #population size
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S = torch.tensor(S_data)
        self.V = torch.tensor(V_data)
        self.I = torch.tensor(I_data)
        self.D = torch.tensor(D_data)
        self.R = torch.tensor(R_data)

        self.losses = []
        self.save = 2 #which file to save to

        self.alpha_tilda = torch.nn.Parameter(torch.rand(1,requires_grad=True))
        self.beta1_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.beta2_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.sigma_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.lbda_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.rho_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        
        #find values for normalization
        self.S_max = max(self.S)
        self.V_max = max(self.V)
        self.I_max = max(self.I)
        self.D_max = max(self.D)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.V_min = min(self.V)
        self.I_min = min(self.I)
        self.D_min = min(self.D)
        self.R_min = min(self.R)

        #normalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.V_hat = (self.V - self.V_min) / (self.V_max - self.V_min)
        self.I_hat = (self.I - self.I_min) / (self.I_max - self.I_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)

        #matrices (x5 for S,V,I,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 5)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 5)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 5)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 5)); self.m4[:, 3] = 1
        self.m5 = torch.zeros((len(self.t), 5)); self.m5[:, 4] = 1

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha_tilda, self.beta1_tilda, self.beta2_tilda, self.sigma_tilda, self.lbda_tilda, self.rho_tilda]))


    @property
    def alpha(self):
        return torch.tanh(self.alpha_tilda) * 3.5e-2

    @property
    def beta1(self):
        return torch.tanh(self.beta2_tilda) *0.5
    
    @property
    def beta2(self):
        return torch.tanh(self.beta2_tilda) *0.5
    
    @property
    def sigma(self):
        return torch.tanh(self.sigma_tilda) *0.1

    @property
    def lbda(self):
        return torch.tanh(self.lbda_tilda) *0.002
    
    @property
    def rho(self):
        return torch.tanh(self.rho_tilda)*0.5

    #nets
    class Net_sidr(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()
            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
            self.fc5=nn.Linear(20, 20)
            self.fc6=nn.Linear(20, 20)
            self.fc7=nn.Linear(20, 20)
            self.fc8=nn.Linear(20, 20)
            self.out=nn.Linear(20, 5) #outputs S, V, I, D, R

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            sidr=F.relu(self.fc5(sidr))
            sidr=F.relu(self.fc6(sidr))
            sidr=F.relu(self.fc7(sidr))
            sidr=F.relu(self.fc8(sidr))
            sidr=self.out(sidr)
            return sidr
            
    def net_f(self, t_batch):
        sidr_hat = self.net_sidr(t_batch)

        S_hat, V_hat, I_hat, D_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3], sidr_hat[:,4]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #V_t
        sidr_hat.backward(self.m2, retain_graph=True)
        V_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_t
        sidr_hat.backward(self.m3, retain_graph=True)
        I_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #D_t
        sidr_hat.backward(self.m4, retain_graph=True)
        D_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m5, retain_graph=True)
        R_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        V = self.V_min + (self.V_max - self.V_min) * V_hat
        I = self.I_min + (self.I_max - self.I_min) * I_hat
        D = self.D_min + (self.D_max - self.D_min) * D_hat      
        R = self.R_min + (self.R_max - self.R_min) * R_hat

        f1_hat = S_hat_t - (-self.beta1/self.N * S * I - self.alpha * S)  / (self.S_max - self.S_min)
        f2_hat = V_hat_t - (self.alpha * S - self.sigma * self.beta2/self.N * V * I)  / (self.V_max - self.V_min)
        f3_hat = I_hat_t - (self.beta1/self.N * S * I + self.sigma * self.beta2/self.N * V * I - self.lbda * I - self.rho * I ) / (self.I_max - self.I_min)
        f4_hat = D_hat_t - (self.lbda * I) / (self.D_max - self.D_min)
        f5_hat = R_hat_t - (self.rho * I ) / (self.R_max - self.R_min)

        return f1_hat, f2_hat, f3_hat, f4_hat, f5_hat, S_hat, V_hat, I_hat, D_hat, R_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
        self.losses = checkpoint['losses']

      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S_pred_list = []
        V_pred_list = []
        I_pred_list = []
        D_pred_list = []
        R_pred_list = []

        f1, f2, f3, f4, f5, S_pred, V_pred, I_pred, D_pred, R_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred)
        V_pred_list.append(self.V_min + (self.V_max - self.V_min) * V_pred) 
        I_pred_list.append(self.I_min + (self.I_max - self.I_min) * I_pred)
        D_pred_list.append(self.D_min + (self.D_max - self.D_min) * D_pred)
        R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

        train_day = 90

        loss = (torch.mean(torch.square(self.S_hat[:train_day] - S_pred[:train_day]))+ 
                torch.mean(torch.square(self.V_hat[:train_day] - V_pred[:train_day]))+
                torch.mean(torch.square(self.I_hat[:train_day] - I_pred[:train_day]))+
                torch.mean(torch.square(self.D_hat[:train_day] - D_pred[:train_day]))+
                torch.mean(torch.square(self.R_hat[:train_day] - R_pred[:train_day]))+
                torch.mean(torch.square(f1[:train_day]))+
                torch.mean(torch.square(f2[:train_day]))+
                torch.mean(torch.square(f3[:train_day]))+
                torch.mean(torch.square(f4[:train_day]))+
                torch.mean(torch.square(f5[:train_day]))
                ) 

        #loss.backward(retain_graph=True)
        loss.backward()
        self.optimizer.step()
        self.scheduler.step(loss) 
        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)
          print('alpha: (goal 3.5e-3 ', self.alpha)
          print('beta1: (goal 0.3 ', self.beta1)
          print('beta2: (goal 0.3 ', self.beta2)
          print('sigma: (goal 0.05 ', self.sigma)
          print('lbda: (goal 1e-3 ', self.lbda)
          print('rho: (goal 0.1 ', self.rho)
          print('#################################') 

      return S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list
# Out:
# Wall time: 0 ns

# %%
# %%time

dinn = DINN(sidr_data[0], sidr_data[1], sidr_data[2], sidr_data[3], 
            sidr_data[4], sidr_data[5]) #in the form of [t,S,V,I,D,R]

learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-6, max_lr=1e-3, step_size_up=1000, mode="exp_range", gamma=0.85, cycle_momentum=False)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(dinn.optimizer, mode='min', factor=0.1, patience=1000, min_lr=1e-6, eps=1e-8)

dinn.scheduler = scheduler

nepochs = int(1e6)

S_pred_list, V_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
# Out:
# starting training...
#
#
# Epoch  0
# alpha: (goal 3.5e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1271], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1271], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0351], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.3024], grad_fn=<MulBackward0>)
# #################################
# d:\python\lib\site-packages\torch\optim\lr_scheduler.py:156: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch  1000
# alpha: (goal 3.5e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1258], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1258], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0354], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.3015], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  2000
# alpha: (goal 3.5e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1241], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1241], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0358], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.3004], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  3000
# alpha: (goal 3.5e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1231], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1231], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0362], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([9.7111e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2995], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  4000
# alpha: (goal 3.5e-3  tensor([0.0007], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1232], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1232], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0364], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([9.2104e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2988], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  5000
# alpha: (goal 3.5e-3  tensor([0.0008], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1244], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1244], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0366], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([8.8176e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2982], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  6000
# alpha: (goal 3.5e-3  tensor([0.0009], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1253], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1253], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0368], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([8.5108e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2979], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  7000
# alpha: (goal 3.5e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1257], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1257], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0368], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([8.3103e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2977], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  8000
# alpha: (goal 3.5e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1258], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1258], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0369], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([8.2552e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2976], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  9000
# alpha: (goal 3.5e-3  tensor([0.0011], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1266], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1266], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0370], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([8.3963e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2973], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  10000
# alpha: (goal 3.5e-3  tensor([0.0011], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1275], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1275], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0372], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([8.6771e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2968], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  11000
# alpha: (goal 3.5e-3  tensor([0.0012], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1283], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1283], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0373], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([8.9934e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2963], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  12000
# alpha: (goal 3.5e-3  tensor([0.0012], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1289], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1289], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0374], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([9.2988e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2958], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  13000
# alpha: (goal 3.5e-3  tensor([0.0013], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1296], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1296], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0376], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([9.6000e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2953], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  14000
# alpha: (goal 3.5e-3  tensor([0.0014], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1302], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1302], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0377], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([9.8846e-05], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2949], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  15000
# alpha: (goal 3.5e-3  tensor([0.0014], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1309], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1309], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0378], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2944], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  16000
# alpha: (goal 3.5e-3  tensor([0.0015], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1315], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1315], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0379], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2939], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  17000
# alpha: (goal 3.5e-3  tensor([0.0015], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1322], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1322], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0380], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2935], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  18000
# alpha: (goal 3.5e-3  tensor([0.0015], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1329], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1329], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0381], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2930], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  19000
# alpha: (goal 3.5e-3  tensor([0.0016], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1336], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1336], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0383], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2925], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  20000
# alpha: (goal 3.5e-3  tensor([0.0016], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1343], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1343], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0384], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2920], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  21000
# alpha: (goal 3.5e-3  tensor([0.0017], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1350], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1350], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0385], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2915], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  22000
# alpha: (goal 3.5e-3  tensor([0.0017], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1358], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1358], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0386], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2911], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  23000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1365], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1365], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0387], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2906], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  24000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1372], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1372], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0388], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2901], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  25000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1379], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1379], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0390], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2896], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  26000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1386], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1386], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0391], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2892], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  27000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1393], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1393], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0392], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2887], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  28000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1399], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1399], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0393], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2883], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  29000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1406], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1406], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0394], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2878], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  30000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1412], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1412], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0395], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2874], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  31000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1419], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1419], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0397], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2869], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  32000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1425], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1425], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0398], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2865], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  33000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1431], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1431], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0399], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2860], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  34000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1437], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1437], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0400], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0001], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2856], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  35000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1442], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1442], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0401], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2852], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  36000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1448], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1448], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0402], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2848], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  37000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1454], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1454], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0403], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2844], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  38000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1460], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1460], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0404], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2840], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  39000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1465], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1465], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0405], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2836], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  40000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1471], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1471], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0406], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2832], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  41000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1476], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1476], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0407], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2828], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  42000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1482], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1482], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0408], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2823], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  43000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1487], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1487], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0409], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2819], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  44000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1493], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1493], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0410], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2816], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  45000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1498], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1498], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0411], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2812], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  46000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1503], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1503], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0412], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2808], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  47000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1509], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1509], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0413], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2804], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  48000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1514], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1514], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0414], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2800], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  49000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1519], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1519], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0415], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2796], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  50000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1524], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1524], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0416], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2792], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  51000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1529], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1529], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0417], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2788], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  52000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1534], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1534], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0418], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2784], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  53000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1540], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1540], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0419], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2781], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  54000
# alpha: (goal 3.5e-3  tensor([0.0018], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1545], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1545], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0420], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2777], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  55000
# alpha: (goal 3.5e-3  tensor([0.0019], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1550], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1550], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0420], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2773], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  56000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1555], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1555], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0421], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2769], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  57000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1560], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1560], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0422], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2765], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  58000
# alpha: (goal 3.5e-3  tensor([0.0020], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1565], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1565], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0423], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2761], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  59000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1570], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1570], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0424], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2757], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  60000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1575], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1575], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0425], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2753], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  61000
# alpha: (goal 3.5e-3  tensor([0.0021], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1580], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1580], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0426], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2749], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  62000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1585], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1585], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0427], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2745], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  63000
# alpha: (goal 3.5e-3  tensor([0.0022], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1590], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1590], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0428], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2741], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  64000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1595], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1595], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0429], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2737], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  65000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1600], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1600], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0430], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2733], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  66000
# alpha: (goal 3.5e-3  tensor([0.0023], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1605], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1605], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0431], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2729], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  67000
# alpha: (goal 3.5e-3  tensor([0.0024], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1610], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1610], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0432], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2725], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  68000
# alpha: (goal 3.5e-3  tensor([0.0024], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1615], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1615], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0433], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2721], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  69000
# alpha: (goal 3.5e-3  tensor([0.0024], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1620], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1620], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0434], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2717], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  70000
# alpha: (goal 3.5e-3  tensor([0.0025], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1625], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1625], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0434], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2713], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  71000
# alpha: (goal 3.5e-3  tensor([0.0025], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1630], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1630], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0435], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2709], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  72000
# alpha: (goal 3.5e-3  tensor([0.0026], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1634], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1634], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0436], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2705], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  73000
# alpha: (goal 3.5e-3  tensor([0.0026], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1639], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1639], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0437], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2701], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  74000
# alpha: (goal 3.5e-3  tensor([0.0027], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1644], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1644], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0438], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2697], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  75000
# alpha: (goal 3.5e-3  tensor([0.0027], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1649], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1649], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0439], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2694], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  76000
# alpha: (goal 3.5e-3  tensor([0.0027], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1654], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1654], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0440], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2690], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  77000
# alpha: (goal 3.5e-3  tensor([0.0028], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1658], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1658], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0441], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2686], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  78000
# alpha: (goal 3.5e-3  tensor([0.0028], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1663], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1663], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0442], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2682], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  79000
# alpha: (goal 3.5e-3  tensor([0.0028], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1668], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1668], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0443], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2678], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  80000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1673], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1673], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0443], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2675], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  81000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1677], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1677], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0444], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2671], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  82000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1682], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1682], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0445], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2667], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  83000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1687], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1687], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0446], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2663], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  84000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1692], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1692], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0447], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2659], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  85000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1696], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1696], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0448], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2655], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  86000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1701], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1701], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0449], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2651], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  87000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1706], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1706], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0449], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2648], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  88000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1710], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1710], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0450], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2644], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  89000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1715], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1715], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0451], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2640], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  90000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1720], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1720], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0452], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2636], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  91000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1725], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1725], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0453], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2632], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  92000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1729], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1729], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0454], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2628], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  93000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1734], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1734], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0454], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2625], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  94000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1738], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1738], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0455], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2621], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  95000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1743], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1743], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0456], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2617], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  96000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1748], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1748], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0457], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2613], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  97000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1752], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1752], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0458], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2609], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  98000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1757], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1757], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0459], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2605], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  99000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1762], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1762], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0459], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2601], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  100000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1766], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1766], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0460], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2598], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  101000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1771], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1771], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0461], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2594], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  102000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1775], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1775], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0462], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2590], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  103000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1780], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1780], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0463], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2586], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  104000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1785], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1785], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0464], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2582], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  105000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1789], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1789], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0464], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2578], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  106000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1794], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1794], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0465], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2575], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  107000
# alpha: (goal 3.5e-3  tensor([0.0029], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1798], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1798], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0466], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2571], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  108000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1803], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1803], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0467], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2567], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  109000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1807], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1807], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0468], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2563], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  110000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1812], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1812], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0468], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2560], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  111000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1816], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1816], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0469], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2556], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  112000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1820], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1820], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0470], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2552], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  113000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1825], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1825], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0471], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2548], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  114000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1829], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1829], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0472], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2545], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  115000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1834], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1834], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0472], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2541], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  116000
# alpha: (goal 3.5e-3  tensor([0.0030], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.1838], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.1838], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0473], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0003], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2537], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  117000
# alpha: (goal 3.5e-3  tensor([0.0031], grad_fn=<MulBackward0>)
# ...
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  961000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3031], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3031], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0651], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  962000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3031], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3031], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0652], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  963000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0652], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  964000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0652], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  965000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0652], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  966000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0652], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  967000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0652], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  968000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0652], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  969000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0652], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  970000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  971000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  972000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  973000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  974000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  975000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  976000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  977000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  978000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  979000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  980000
# alpha: (goal 3.5e-3  tensor([0.0041], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  981000
# alpha: (goal 3.5e-3  tensor([0.0041], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  982000
# alpha: (goal 3.5e-3  tensor([0.0041], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3030], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  983000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3029], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3029], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  984000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  985000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  986000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  987000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  988000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  989000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  990000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0653], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  991000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0654], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  992000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0654], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  993000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0654], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  994000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0654], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  995000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0654], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1010], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  996000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0654], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  997000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3029], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3029], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0654], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  998000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3029], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3029], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0654], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  999000
# alpha: (goal 3.5e-3  tensor([0.0042], grad_fn=<MulBackward0>)
# beta1: (goal 0.3  tensor([0.3029], grad_fn=<MulBackward0>)
# beta2: (goal 0.3  tensor([0.3029], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0654], grad_fn=<MulBackward0>)
# lbda: (goal 1e-3  tensor([0.0010], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1011], grad_fn=<MulBackward0>)
# #################################
# Wall time: 1h 38min 14s

# %%
plt.plot(dinn.losses, color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss'),
# Out:
# (Text(0, 0.5, 'Loss'),)

# %%
fig = plt.figure(figsize=(12,12))

ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')



ax.scatter(sidr_data[0], sidr_data[1], color = 'darkgreen', label='Susceptible Data', s=15)
ax.plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[2], color = 'blue', label='Vaccinated Data', s=15)
ax.plot(sidr_data[0], V_pred_list[0].detach().numpy(), 'lightblue', alpha=0.9, lw=2, label='Vaccinated Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[3], color = 'red', label='Infected Data', s=15)
ax.plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'pink', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[4], color = 'black', label='Dead Data', s=15)
ax.plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'grey', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[5], color = 'green', label='Recovered Data', s=15)
ax.plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'lightgreen', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')


ax.set_xlabel('Time /days',size = 20)
ax.set_ylabel('Number',size = 20)

ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
plt.xticks(size = 20)
plt.yticks(size = 20)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend(prop={'size':20})
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('output8')
plt.show()

# %%
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

fig, ax = plt.subplots(2, 3, figsize = (12,12))

for i in range(2):
    for j in range(3):
        ax[i, j].set_facecolor('xkcd:white')


train_day = 90

ax[0, 0].scatter(sidr_data[0][:train_day], sidr_data[1][:train_day], c = 'black', alpha=0.5, lw=2, label='Susceptible Data')
ax[0, 0].scatter(sidr_data[0][train_day:], sidr_data[1][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 0].plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax[0, 1].scatter(sidr_data[0][:train_day], sidr_data[2][:train_day], c = 'black', alpha=0.5, lw=2, label='Vaccinated Data')
ax[0, 1].scatter(sidr_data[0][train_day:], sidr_data[2][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 1].plot(sidr_data[0], V_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Vaccinated Prediction', linestyle='dashed')

ax[0, 2].scatter(sidr_data[0][:train_day], sidr_data[3][:train_day], c = 'violet', alpha=0.5, lw=2, label='Infected Data')
ax[0, 2].scatter(sidr_data[0][train_day:], sidr_data[3][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 2].plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'black', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

ax[1, 0].scatter(sidr_data[0][:train_day], sidr_data[4][:train_day], c = 'black', alpha=0.5, lw=2, label='Dead Data')
ax[1, 0].scatter(sidr_data[0][train_day:], sidr_data[4][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 0].plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax[1, 1].scatter(sidr_data[0][:train_day], sidr_data[5][:train_day], c = 'blue', alpha=0.5, lw=2, label='Recovered Data')
ax[1, 1].scatter(sidr_data[0][train_day:], sidr_data[5][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 1].plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')

for i in range(2):
    for j in range(3):
        ax[i, j].set_xlabel('Time /days',size = 20)
        ax[i, j].set_ylabel('Number',size = 20)
        ax[i, j].yaxis.set_tick_params(length=0)
        ax[i, j].xaxis.set_tick_params(length=0)
        legend = ax[i, j].legend(prop={'size':18})
        legend.get_frame().set_alpha(0.5)
        for spine in ('top', 'right', 'bottom', 'left'):
            ax[i, j].spines[spine].set_visible(False)
plt.savefig('output8_2')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initial conditions
N = 3e8

S0 = N - 1
V0 = 0
I0 = 1
D0 = 0
R0 = 0
# A grid of time points (in days)
t = np.linspace(0, 500, 100) 

#parameters
alpha = dinn.alpha.detach().numpy().item()
beta1 = dinn.beta1.detach().numpy().item()
beta2 = dinn.beta2.detach().numpy().item()
sigma = dinn.sigma.detach().numpy().item()
lbda = dinn.lbda.detach().numpy().item()
rho = dinn.rho.detach().numpy().item()
print('alpha: (goal 3.5e-3 ', alpha)
print('beta1: (goal 0.3 ', beta1)
print('beta2: (goal 0.3 ', beta2)
print('sigma: (goal 0.05 ', sigma)
print('lbda: (goal 1e-3 ', lbda)
print('rho: (goal 0.1 ', rho)
print('#################################')

# The SIR model differential equations.
def deriv(y, t, alpha, beta1, beta2, sigma, lbda, rho):
    S, V, I, D, R = y
    dSdt = - beta1/N * S * I - alpha * S
    dVdt = alpha * S - sigma * beta2/N * V * I
    dIdt = beta1/N * S * I + sigma * beta2/N * V * I - lbda * I - rho * I 
    dDdt = lbda * I
    dRdt = rho * I

    return dSdt, dVdt, dIdt, dDdt, dRdt


# Initial conditions vector
y0 = S0, V0, I0, D0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(alpha, beta1, beta2, sigma, lbda, rho))
S, V, I, D, R = ret.T

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w', figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, S, 'purple', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
ax.plot(t, sidr_data[1], 'violet', alpha=0.5, lw=2, label='Susceptible')

ax.plot(t, V, 'blue', alpha=0.5, lw=2, label='Learnable Param Vaccinated', linestyle='dashed')
ax.plot(t, sidr_data[2], 'dodgerblue', alpha=0.5, lw=2, label='Vaccinated')

ax.plot(t, I, 'red', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.plot(t, sidr_data[3], 'pink', alpha=0.5, lw=2, label='Infected')

ax.plot(t, D, 'black', alpha=0.5, lw=2, label='Learnable Param Dead', linestyle='dashed')
ax.plot(t, sidr_data[4], 'grey', alpha=0.5, lw=2, label='Dead')

ax.plot(t, R, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Recovered', linestyle='dashed')
ax.plot(t, sidr_data[5], 'green', alpha=0.5, lw=2, label='Recovered')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('output8_3')
plt.show()
# Out:
# alpha: (goal 3.5e-3  0.004188839346170425
# beta1: (goal 0.3  0.30287981033325195
# beta2: (goal 0.3  0.30287981033325195
# sigma: (goal 0.05  0.06542079895734787
# lbda: (goal 1e-3  0.0009813199285417795
# rho: (goal 0.1  0.10107310116291046
# #################################

# %%
#calculate relative MSE loss
import math

S_total_loss = 0
S_den = 0
V_total_loss = 0
V_den = 0
I_total_loss = 0
I_den = 0
D_total_loss = 0
D_den = 0
R_total_loss = 0
R_den = 0

for timestep in range(len(t)):
  S_value = sidr_data[1][timestep] - S[timestep]
  S_total_loss += S_value**2
  S_den += (sidr_data[1][timestep])**2

  V_value = sidr_data[1][timestep] - V[timestep]
  V_total_loss += V_value**2
  V_den += (sidr_data[1][timestep])**2

  I_value = sidr_data[3][timestep] - I[timestep]
  I_total_loss += I_value**2
  I_den += (sidr_data[3][timestep])**2

  D_value = sidr_data[4][timestep] - D[timestep]
  D_total_loss += D_value**2
  D_den += (sidr_data[4][timestep])**2

  R_value = sidr_data[5][timestep] - R[timestep]
  R_total_loss += R_value**2
  R_den += (sidr_data[5][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)
V_total_loss = math.sqrt(V_total_loss/V_den)
I_total_loss = math.sqrt(I_total_loss/I_den)
D_total_loss = math.sqrt(D_total_loss/D_den)
R_total_loss = math.sqrt(R_total_loss/R_den)

print('S_total_loss: ', S_total_loss)
print('V_total_loss: ', V_total_loss)
print('I_total_loss: ', I_total_loss)
print('D_total_loss: ', D_total_loss)
print('R_total_loss: ', R_total_loss)
# Out:
# S_total_loss:  0.04921600041515325
# V_total_loss:  1.1206299399798894
# I_total_loss:  0.2862679649612911
# D_total_loss:  0.18214602787539574
# R_total_loss:  0.15821383424634258
