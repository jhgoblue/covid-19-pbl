# %%
import torch
from torch.autograd import grad
import torch.nn as nn
from numpy import genfromtxt
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F

sidr_data = genfromtxt('sveidr_sim_SA.csv', delimiter=',') #in the form of [t,S,V,I,D,R]

torch.manual_seed(1234)

# %%
sidr_data.shape
# Out:
# (7, 100)

# %%
# %%time

PATH = 'svidr_norm_simple' 

class DINN(nn.Module):
    def __init__(self, t, S_data, V_data, E_data, I_data, D_data, R_data): #[t,S,V,I,D,R]
        super(DINN, self).__init__()
        self.N = 3.5e7 #population size
        self.t = torch.tensor(t, requires_grad=True)
        self.t_float = self.t.float()
        self.t_batch = torch.reshape(self.t_float, (len(self.t),1)) #reshape for batch 
        self.S = torch.tensor(S_data)
        self.E = torch.tensor(E_data)
        self.V = torch.tensor(V_data)
        self.I = torch.tensor(I_data)
        self.D = torch.tensor(D_data)
        self.R = torch.tensor(R_data)

        self.losses = []
        self.save = 2 #which file to save to

        self.alpha_tilda = torch.nn.Parameter(torch.rand(1,requires_grad=True))
        self.beta_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.gamma_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.sigma_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.lbda_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        self.rho_tilda = torch.nn.Parameter(torch.rand(1, requires_grad=True))
        
        #find values for normalization
        self.S_max = max(self.S)
        self.V_max = max(self.V)
        self.E_max = max(self.E)
        self.I_max = max(self.I)
        self.D_max = max(self.D)
        self.R_max = max(self.R)
        self.S_min = min(self.S)
        self.V_min = min(self.V)
        self.E_min = min(self.E)
        self.I_min = min(self.I)
        self.D_min = min(self.D)
        self.R_min = min(self.R)

        #normalize
        self.S_hat = (self.S - self.S_min) / (self.S_max - self.S_min)
        self.V_hat = (self.V - self.V_min) / (self.V_max - self.V_min)
        self.E_hat = (self.E - self.E_min) / (self.E_max - self.E_min)
        self.I_hat = (self.I - self.I_min) / (self.I_max - self.I_min)
        self.D_hat = (self.D - self.D_min) / (self.D_max - self.D_min)
        self.R_hat = (self.R - self.R_min) / (self.R_max - self.R_min)

        #matrices (x6 for S,V,E,I,D,R) for the gradients
        self.m1 = torch.zeros((len(self.t), 6)); self.m1[:, 0] = 1
        self.m2 = torch.zeros((len(self.t), 6)); self.m2[:, 1] = 1
        self.m3 = torch.zeros((len(self.t), 6)); self.m3[:, 2] = 1
        self.m4 = torch.zeros((len(self.t), 6)); self.m4[:, 3] = 1
        self.m5 = torch.zeros((len(self.t), 6)); self.m5[:, 4] = 1
        self.m6 = torch.zeros((len(self.t), 6)); self.m6[:, 4] = 1        

        #NN
        self.net_sidr = self.Net_sidr()
        self.params = list(self.net_sidr.parameters())
        self.params.extend(list([self.alpha_tilda, self.beta_tilda, self.gamma_tilda, self.sigma_tilda, self.lbda_tilda, self.rho_tilda]))


    @property
    def alpha(self):
        return torch.tanh(self.alpha_tilda) * 3.5e-3

    @property
    def beta(self):
        return torch.tanh(self.beta_tilda) *0.5
    
    @property
    def gamma(self):
        return torch.tanh(self.gamma_tilda) *0.3
    
    @property
    def sigma(self):
        return torch.tanh(self.sigma_tilda) *0.1

    @property
    def lbda(self):
        return torch.tanh(self.lbda_tilda) *0.1
    
    @property
    def rho(self):
        return torch.tanh(self.rho_tilda)*0.5

    #nets
    class Net_sidr(nn.Module): # input = [t]
        def __init__(self):
            super(DINN.Net_sidr, self).__init__()
            self.fc1=nn.Linear(1, 20) #takes 100 t's
            self.fc2=nn.Linear(20, 20)
            self.fc3=nn.Linear(20, 20)
            self.fc4=nn.Linear(20, 20)
            self.fc5=nn.Linear(20, 20)
            self.fc6=nn.Linear(20, 20)
            self.fc7=nn.Linear(20, 20)
            self.fc8=nn.Linear(20, 20)
            self.out=nn.Linear(20, 6) #outputs S, V, E, I, D, R

        def forward(self, t_batch):
            sidr=F.relu(self.fc1(t_batch))
            sidr=F.relu(self.fc2(sidr))
            sidr=F.relu(self.fc3(sidr))
            sidr=F.relu(self.fc4(sidr))
            sidr=F.relu(self.fc5(sidr))
            sidr=F.relu(self.fc6(sidr))
            sidr=F.relu(self.fc7(sidr))
            sidr=F.relu(self.fc8(sidr))
            sidr=self.out(sidr)
            return sidr
            
    def net_f(self, t_batch):
        sidr_hat = self.net_sidr(t_batch)

        S_hat, V_hat, E_hat, I_hat, D_hat, R_hat = sidr_hat[:,0], sidr_hat[:,1], sidr_hat[:,2], sidr_hat[:,3], sidr_hat[:,4], sidr_hat[:,5]

        #S_t
        sidr_hat.backward(self.m1, retain_graph=True)
        S_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #V_t
        sidr_hat.backward(self.m2, retain_graph=True)
        V_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #E_t
        sidr_hat.backward(self.m3, retain_graph=True)
        E_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #I_t
        sidr_hat.backward(self.m4, retain_graph=True)
        I_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #D_t
        sidr_hat.backward(self.m5, retain_graph=True)
        D_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #R_t
        sidr_hat.backward(self.m6, retain_graph=True)
        R_hat_t = self.t.grad.clone()
        self.t.grad.zero_()

        #unnormalize
        S = self.S_min + (self.S_max - self.S_min) * S_hat
        V = self.V_min + (self.V_max - self.V_min) * V_hat
        E = self.E_min + (self.E_max - self.E_min) * E_hat
        I = self.I_min + (self.I_max - self.I_min) * I_hat
        D = self.D_min + (self.D_max - self.D_min) * D_hat      
        R = self.R_min + (self.R_max - self.R_min) * R_hat

        f1_hat = S_hat_t - (-self.beta/self.N * S * I - self.alpha * S)  / (self.S_max - self.S_min)
        f2_hat = V_hat_t - (self.alpha * S - self.sigma * self.beta/self.N * V * I)  / (self.V_max - self.V_min)
        f3_hat = E_hat_t - (self.beta/self.N * S * I + self.sigma * self.beta/self.N * V * I - self.gamma * E) / (self.E_max - self.E_min)
        f4_hat = I_hat_t - (self.gamma * E - self.lbda * I - self.rho * I ) / (self.I_max - self.I_min)
        f5_hat = D_hat_t - (self.lbda * I) / (self.D_max - self.D_min)
        f6_hat = R_hat_t - (self.rho * I ) / (self.R_max - self.R_min)

        return f1_hat, f2_hat, f3_hat, f4_hat, f5_hat, f6_hat, S_hat, V_hat, E_hat, I_hat, D_hat, R_hat
    
    def load(self):
      # Load checkpoint
      try:
        checkpoint = torch.load(PATH + str(self.save)+'.pt') 
        print('\nloading pre-trained model...')
        self.load_state_dict(checkpoint['model'])
        self.optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
        self.scheduler.load_state_dict(checkpoint['scheduler'])
        epoch = checkpoint['epoch']
        self.losses = checkpoint['losses']

      except RuntimeError :
          print('changed the architecture, ignore')
          pass
      except FileNotFoundError:
          pass

    def train(self, n_epochs):
      #try loading
      self.load()

      #train
      print('\nstarting training...\n')
      
      for epoch in range(n_epochs):
        #lists to hold the output (maintain only the final epoch)
        S_pred_list = []
        V_pred_list = []
        E_pred_list = []
        I_pred_list = []
        D_pred_list = []
        R_pred_list = []

        f1, f2, f3, f4, f5, f6, S_pred, V_pred, E_pred, I_pred, D_pred, R_pred = self.net_f(self.t_batch)
        self.optimizer.zero_grad()

        S_pred_list.append(self.S_min + (self.S_max - self.S_min) * S_pred)
        V_pred_list.append(self.V_min + (self.V_max - self.V_min) * V_pred) 
        E_pred_list.append(self.E_min + (self.E_max - self.E_min) * E_pred) 
        I_pred_list.append(self.I_min + (self.I_max - self.I_min) * I_pred)
        D_pred_list.append(self.D_min + (self.D_max - self.D_min) * D_pred)
        R_pred_list.append(self.R_min + (self.R_max - self.R_min) * R_pred)

        train_day = 90

        loss = (torch.mean(torch.square(self.S_hat[:train_day] - S_pred[:train_day]))+ 
                torch.mean(torch.square(self.V_hat[:train_day] - V_pred[:train_day]))+
                torch.mean(torch.square(self.E_hat[:train_day] - E_pred[:train_day]))+
                torch.mean(torch.square(self.I_hat[:train_day] - I_pred[:train_day]))+
                torch.mean(torch.square(self.D_hat[:train_day] - D_pred[:train_day]))+
                torch.mean(torch.square(self.R_hat[:train_day] - R_pred[:train_day]))+
                torch.mean(torch.square(f1[:train_day]))+
                torch.mean(torch.square(f2[:train_day]))+
                torch.mean(torch.square(f3[:train_day]))+
                torch.mean(torch.square(f4[:train_day]))+
                torch.mean(torch.square(f5[:train_day]))+
                torch.mean(torch.square(f6[:train_day]))
                ) 

        #loss.backward(retain_graph=True)
        loss.backward()
        self.optimizer.step()
        self.scheduler.step(loss) 
        self.losses.append(loss.item())

        if epoch % 1000 == 0:          
          print('\nEpoch ', epoch)
          print('alpha: (goal 3.5e-4 ', self.alpha)
          print('beta: (goal 0.3 ', self.beta)
          print('gamma: (goal 0.18 ', self.gamma)
          print('sigma: (goal 0.05 ', self.sigma)
          print('lbda: (goal 0.06 ', self.lbda)
          print('rho: (goal 0.1 ', self.rho)
          print('#################################') 

      return S_pred_list, V_pred_list, E_pred_list, I_pred_list, D_pred_list, R_pred_list
# Out:
# Wall time: 0 ns

# %%
# %%time

dinn = DINN(sidr_data[0], sidr_data[1], sidr_data[2], sidr_data[3], 
            sidr_data[4], sidr_data[5], sidr_data[6]) #in the form of [t,S,V,E,I,D,R]

learning_rate = 1e-5
optimizer = optim.Adam(dinn.params, lr = learning_rate)
dinn.optimizer = optimizer

# scheduler = torch.optim.lr_scheduler.CyclicLR(dinn.optimizer, base_lr=1e-6, max_lr=1e-3, step_size_up=1000, mode="exp_range", gamma=0.85, cycle_momentum=False)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(dinn.optimizer, mode='min', factor=0.1, patience=1000, min_lr=1e-6, eps=1e-8)

dinn.scheduler = scheduler

nepochs = int(5e5)

S_pred_list, V_pred_list, E_pred_list, I_pred_list, D_pred_list, R_pred_list = dinn.train(nepochs) #train
# Out:
# starting training...
#
#
# Epoch  0
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1908], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.0762], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0351], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0058], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.3024], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  1000
# alpha: (goal 3.5e-4  tensor([9.0274e-05], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1842], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.0802], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0337], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0043], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2975], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  2000
# alpha: (goal 3.5e-4  tensor([0.0001], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1808], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.0843], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0327], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0031], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2937], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  3000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1794], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.0871], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0320], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0021], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2904], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  4000
# alpha: (goal 3.5e-4  tensor([0.0002], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1788], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.0898], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0314], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0012], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2871], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  5000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1807], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.0925], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0312], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0002], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2838], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  6000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1784], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.0951], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0316], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0008], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2804], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  7000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1715], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.0977], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0325], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0018], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2769], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  8000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1652], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1003], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0334], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0028], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2733], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  9000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1601], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1028], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0342], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0038], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2698], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  10000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1553], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1055], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0345], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0048], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2660], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  11000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1506], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1083], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0339], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0059], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2622], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  12000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1470], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1111], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0333], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0069], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2582], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  13000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1453], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1138], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0335], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0080], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2542], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  14000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1479], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1165], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0348], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0091], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2501], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  15000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1530], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1192], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0360], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0101], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2460], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  16000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1595], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1218], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0373], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0112], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2419], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  17000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1657], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1244], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0385], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0123], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2378], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  18000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1714], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1269], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0396], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0132], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2338], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  19000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1767], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1292], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0407], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0142], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2299], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  20000
# alpha: (goal 3.5e-4  tensor([0.0003], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1816], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1315], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0416], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0151], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2261], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  21000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1863], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1336], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0425], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0160], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2223], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  22000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1909], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1357], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0434], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0169], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2185], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  23000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1952], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1378], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0442], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0178], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2148], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  24000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.1993], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1398], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0450], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0187], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2110], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  25000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2034], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1418], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0458], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0196], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2072], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  26000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2074], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1438], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0466], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0204], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.2034], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  27000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2114], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1457], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0474], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0212], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1997], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  28000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2153], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1475], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0481], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0221], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1959], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  29000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2192], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1492], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0488], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0229], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1922], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  30000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2230], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1508], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0496], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0236], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1886], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  31000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2267], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1522], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0503], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0244], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1850], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  32000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2303], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1534], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0510], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0251], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1815], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  33000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2339], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1542], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0517], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0258], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1781], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  34000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2373], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1543], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0523], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0264], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1748], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  35000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2405], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1537], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0529], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0269], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1716], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  36000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2434], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1528], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0534], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0273], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1686], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  37000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2459], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1519], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0539], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0274], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1657], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  38000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2481], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1513], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0542], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0270], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1632], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  39000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2499], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1513], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0544], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0261], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1610], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  40000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2515], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1514], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0545], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0250], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1592], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  41000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2527], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1517], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0543], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0239], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1580], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  42000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2538], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1522], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0537], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0229], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1572], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  43000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2549], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1528], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0531], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0219], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1566], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  44000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2562], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1535], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0523], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0209], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1563], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  45000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2577], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1543], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0516], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0199], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1561], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  46000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2593], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1553], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0509], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0190], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1560], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  47000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2608], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1561], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0502], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0180], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1558], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  48000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2622], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1570], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0494], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0170], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1556], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  49000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2632], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1575], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0487], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0161], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1551], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  50000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2640], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1580], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0479], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0151], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1546], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  51000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2648], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1584], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0472], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0141], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1540], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  52000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2654], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1588], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0464], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0132], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1535], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  53000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2662], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1592], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0457], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0122], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1527], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  54000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2668], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1596], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0449], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0112], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1522], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  55000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2673], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1599], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0442], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0102], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1515], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  56000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2679], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1602], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0434], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0093], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1508], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  57000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2685], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1606], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0426], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0083], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1501], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  58000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2690], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1609], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0418], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0073], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1494], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  59000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2695], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1612], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0410], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0063], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1487], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  60000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2701], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1615], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0402], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0053], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1480], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  61000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2705], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1617], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0394], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0044], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1473], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  62000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2711], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1620], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0386], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0034], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1466], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  63000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2714], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1622], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0378], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0024], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1458], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  64000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2719], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1625], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0370], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0014], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1451], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  65000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2724], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1628], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0362], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([-0.0004], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1443], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  66000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2728], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1630], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0354], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0006], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1436], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  67000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2732], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1632], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0346], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0015], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1427], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  68000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2736], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1635], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0337], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0025], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1420], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  69000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2740], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1637], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0329], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0035], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1412], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  70000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2745], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1640], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0321], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0045], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1405], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  71000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2749], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1642], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0312], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0055], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1398], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  72000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2754], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1645], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0304], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0064], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1391], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  73000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2762], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1648], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0295], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0074], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1384], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  74000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2765], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1651], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0287], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0084], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1378], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  75000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2772], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1655], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0278], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0094], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1371], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  76000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2775], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1656], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0270], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0103], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1362], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  77000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2778], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1658], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0261], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0113], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1354], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  78000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2781], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1660], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0253], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0123], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1345], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  79000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2785], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1662], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0244], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0132], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1339], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  80000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2789], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1664], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0236], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0142], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1332], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  81000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2794], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1667], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0227], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0151], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1324], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  82000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2798], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1669], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0219], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0161], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1317], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  83000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2803], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1672], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0210], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0170], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1310], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  84000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2807], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1675], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0202], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0180], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1303], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  85000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2812], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1677], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0193], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0189], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1296], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  86000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2818], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1680], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0185], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0199], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1290], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  87000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2822], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1683], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0177], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0208], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1283], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  88000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2827], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1686], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0169], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0217], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1276], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  89000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2832], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1688], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0160], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0226], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1269], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  90000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2836], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1691], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0152], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0236], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1263], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  91000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2842], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1694], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0144], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0245], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1256], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  92000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2847], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1696], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0136], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0254], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1248], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  93000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2850], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1699], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0129], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0263], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1243], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  94000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2855], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1701], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0121], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0272], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1236], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  95000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2859], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1704], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0113], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0281], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1230], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  96000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2864], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1706], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0105], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0290], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1223], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  97000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2870], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1710], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0098], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0298], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1217], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  98000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2874], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1712], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0091], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0307], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1211], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  99000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2881], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1715], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0084], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0316], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1203], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  100000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2884], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1718], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0078], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0325], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1199], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  101000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2889], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1721], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0072], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0333], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1193], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  102000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2893], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1723], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0067], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0342], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1186], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  103000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2897], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1725], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0063], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0350], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1180], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  104000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2901], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1728], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0061], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0358], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1174], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  105000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2906], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1731], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0059], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0367], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1168], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  106000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2910], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1733], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0058], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0375], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1162], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  107000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2914], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1735], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0058], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0383], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1157], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  108000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2918], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1738], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0060], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0391], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1151], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  109000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2921], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1740], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0062], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0399], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1145], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  110000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2926], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1743], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0065], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0407], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1139], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  111000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2930], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1744], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0073], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0415], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1129], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  112000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2934], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1747], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0081], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0423], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1124], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  113000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2938], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1750], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0088], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0431], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1120], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  114000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2943], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1753], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0096], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0438], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1114], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  115000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2946], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1755], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0103], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0446], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1109], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  116000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2950], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1758], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0111], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0454], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1104], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  117000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2953], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1760], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0118], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0461], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1099], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  118000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.2957], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1762], grad_fn=<MulBackward0>)
# ...
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1008], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  461000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3017], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0479], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1008], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  462000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3017], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0479], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1008], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  463000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3018], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0480], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  464000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3017], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0480], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1008], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  465000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3017], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0481], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  466000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3017], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0481], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1008], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  467000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3017], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0482], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  468000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3017], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0482], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1008], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  469000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3017], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0483], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  470000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3017], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0483], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1008], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  471000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3017], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0484], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  472000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3016], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0484], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  473000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3015], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1809], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0485], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  474000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3015], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1809], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0485], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  475000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3015], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1809], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0486], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  476000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3016], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0486], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1008], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  477000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3016], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0487], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  478000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3016], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0487], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1008], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  479000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3016], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0488], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  480000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3016], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1810], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0488], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  481000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3015], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1809], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0489], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  482000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3014], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1809], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0489], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  483000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3015], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1809], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0490], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  484000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3014], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0491], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  485000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3013], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0491], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  486000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3014], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0492], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  487000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3013], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0492], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  488000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3013], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0493], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  489000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3012], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1807], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0493], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0601], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1005], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  490000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3012], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0494], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  491000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3013], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0494], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  492000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3014], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0495], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  493000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3013], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0495], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  494000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3014], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0496], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  495000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3013], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0496], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  496000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3013], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0497], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1007], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  497000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3013], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0497], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  498000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3013], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0498], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
#
# Epoch  499000
# alpha: (goal 3.5e-4  tensor([0.0004], grad_fn=<MulBackward0>)
# beta: (goal 0.3  tensor([0.3013], grad_fn=<MulBackward0>)
# gamma: (goal 0.18  tensor([0.1808], grad_fn=<MulBackward0>)
# sigma: (goal 0.05  tensor([0.0498], grad_fn=<MulBackward0>)
# lbda: (goal 0.06  tensor([0.0602], grad_fn=<MulBackward0>)
# rho: (goal 0.1  tensor([0.1006], grad_fn=<MulBackward0>)
# #################################
# Wall time: 51min 25s

# %%
plt.plot(dinn.losses, color = 'teal')
plt.xlabel('Epochs')
plt.ylabel('Loss')
print('total loss: ', dinn.losses[-1])
# Out:
# total loss:  3.554363315686638e-05

# %%
fig = plt.figure(figsize=(12,12))

ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)
ax.set_facecolor('xkcd:white')

ax.scatter(sidr_data[0], sidr_data[1], color = 'darkgreen', label='Susceptible Data', s=15)
ax.plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[2], color = 'blue', label='Vaccinated Data', s=15)
ax.plot(sidr_data[0], V_pred_list[0].detach().numpy(), 'lightblue', alpha=0.9, lw=2, label='Vaccinated Prediction', linestyle='dashed')

ax.scatter(sidr_data[0], sidr_data[3], color = 'darkviolet', label='Exposed Data', s=15)
ax.plot(sidr_data[0], E_pred_list[0].detach().numpy(), 'violet', alpha=0.9, lw=2, label='Exposed Prediction', linestyle='dashed')

ax.scatter(sidr_data[0], sidr_data[4], color = 'red', label='Infected Data', s=15)
ax.plot(sidr_data[0], I_pred_list[0].detach().numpy(), 'pink', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[5], color = 'black', label='Dead Data', s=15)
ax.plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'grey', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')


ax.scatter(sidr_data[0], sidr_data[6], color = 'green', label='Recovered Data', s=15)
ax.plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'lightgreen', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')


ax.set_xlabel('Time /days',size = 20)
ax.set_ylabel('Number',size = 20)

ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
plt.xticks(size = 20)
plt.yticks(size = 20)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend(prop={'size':20})
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('SA_output1_1.png')
plt.show()

# %%
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

fig, ax = plt.subplots(2, 3, figsize = (12,12))

for i in range(2):
    for j in range(3):
        ax[i, j].set_facecolor('xkcd:white')


train_day = 90

ax[0, 0].scatter(sidr_data[0][:train_day], sidr_data[1][:train_day], c = 'black', alpha=0.5, lw=2, label='Susceptible Data')
ax[0, 0].scatter(sidr_data[0][train_day:], sidr_data[1][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 0].plot(sidr_data[0], S_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Susceptible Prediction', linestyle='dashed')

ax[0, 1].scatter(sidr_data[0][:train_day], sidr_data[2][:train_day], c = 'black', alpha=0.5, lw=2, label='Vaccinated Data')
ax[0, 1].scatter(sidr_data[0][train_day:], sidr_data[2][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 1].plot(sidr_data[0], V_pred_list[0].detach().numpy(), 'red', alpha=0.9, lw=2, label='Vaccinated Prediction', linestyle='dashed')

ax[0, 2].scatter(sidr_data[0][:train_day], sidr_data[3][:train_day], c = 'violet', alpha=0.5, lw=2, label='Exposed Data')
ax[0, 2].scatter(sidr_data[0][train_day:], sidr_data[3][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[0, 2].plot(sidr_data[0], E_pred_list[0].detach().numpy(), 'black', alpha=0.9, lw=2, label='Exposed Prediction', linestyle='dashed')

ax[1, 0].scatter(sidr_data[0][:train_day], sidr_data[4][:train_day], c = 'violet', alpha=0.5, lw=2, label='Infected Data')
ax[1, 0].scatter(sidr_data[0][train_day:], sidr_data[4][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 0].plot(sidr_data[0], E_pred_list[0].detach().numpy(), 'black', alpha=0.9, lw=2, label='Infected Prediction', linestyle='dashed')

ax[1, 1].scatter(sidr_data[0][:train_day], sidr_data[5][:train_day], c = 'black', alpha=0.5, lw=2, label='Dead Data')
ax[1, 1].scatter(sidr_data[0][train_day:], sidr_data[5][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 1].plot(sidr_data[0], D_pred_list[0].detach().numpy(), 'green', alpha=0.9, lw=2, label='Dead Prediction', linestyle='dashed')

ax[1, 2].scatter(sidr_data[0][:train_day], sidr_data[6][:train_day], c = 'blue', alpha=0.5, lw=2, label='Recovered Data')
ax[1, 2].scatter(sidr_data[0][train_day:], sidr_data[6][train_day:], c = 'gold', alpha=0.5, lw=5, label='Future Data')
ax[1, 2].plot(sidr_data[0], R_pred_list[0].detach().numpy(), 'teal', alpha=0.9, lw=2, label='Recovered Prediction', linestyle='dashed')

for i in range(2):
    for j in range(3):
        ax[i, j].set_xlabel('Time /days',size = 20)
        ax[i, j].set_ylabel('Number',size = 20)
        ax[i, j].yaxis.set_tick_params(length=0)
        ax[i, j].xaxis.set_tick_params(length=0)
        legend = ax[i, j].legend(prop={'size':18})
        legend.get_frame().set_alpha(0.5)
        for spine in ('top', 'right', 'bottom', 'left'):
            ax[i, j].spines[spine].set_visible(False)
plt.savefig('SA_output1_2.png')
plt.show()

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# Initial conditions
N = 3.5e7

S0 = N -1
V0 = 0
E0 = 0
I0 = 1
D0 = 0
R0 = 0
# A grid of time points (in days)
t = np.linspace(0, 500, 100) 

#parameters
alpha = 3.5e-4
beta = 0.3
gamma = 0.18
sigma = 0.05
lbda = 0.06
rho = 0.1

# The SIR model differential equations.
def deriv(y, t, alpha, beta, gamma, sigma, lbda, rho):
    S, V, E, I, D, R = y
    dSdt = - beta/N * S * I - alpha * S
    dVdt = alpha * S - sigma * beta/N * V * I
    dEdt = beta/N * S * I + sigma * beta/N * V * I - gamma * E
    dIdt = gamma * E - lbda * I - rho * I 
    dDdt = lbda * I
    dRdt = rho * I

    return dSdt, dVdt, dEdt, dIdt, dDdt, dRdt

# Initial conditions vector
y0 = S0, V0, E0, I0, D0, R0
# Integrate the SIR equations over the time grid, t.
ret = odeint(deriv, y0, t, args=(alpha, beta, gamma, sigma, lbda, rho))
S, V, E, I, D, R = ret.T

#parameters
alpha = dinn.alpha.detach().numpy().item()
beta = dinn.beta.detach().numpy().item()
gamma = dinn.gamma.detach().numpy().item()
sigma = dinn.sigma.detach().numpy().item()
lbda = dinn.lbda.detach().numpy().item()
rho = dinn.rho.detach().numpy().item()
print('alpha: (goal 3.5e-4 ', alpha)
print('beta: (goal 0.3 ', beta)
print('gamma: (goal 0.18 ', gamma)
print('sigma: (goal 0.05 ', sigma)
print('lbda: (goal 0.06 ', lbda)
print('rho: (goal 0.1 ', rho)
print('#################################')

# Plot the data on two separate curves for S(t), I(t)
fig = plt.figure(facecolor='w', figsize=(12,12))
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, S, 'purple', alpha=0.5, lw=2, label='Learnable Param Susceptible', linestyle='dashed')
ax.plot(t, sidr_data[1], 'violet', alpha=0.5, lw=2, label='Susceptible')

ax.plot(t, V, 'blue', alpha=0.5, lw=2, label='Learnable Param Vaccinated', linestyle='dashed')
ax.plot(t, sidr_data[2], 'dodgerblue', alpha=0.5, lw=2, label='Vaccinated')

ax.plot(t, E, 'darkviolet', alpha=0.5, lw=2, label='Learnable Param Exposed', linestyle='dashed')
ax.plot(t, sidr_data[3], 'violet', alpha=0.5, lw=2, label='Exposed')

ax.plot(t, I, 'red', alpha=0.5, lw=2, label='Learnable Param Infected', linestyle='dashed')
ax.plot(t, sidr_data[4], 'pink', alpha=0.5, lw=2, label='Infected')

ax.plot(t, D, 'black', alpha=0.5, lw=2, label='Learnable Param Dead', linestyle='dashed')
ax.plot(t, sidr_data[5], 'grey', alpha=0.5, lw=2, label='Dead')

ax.plot(t, R, 'darkgreen', alpha=0.5, lw=2, label='Learnable Param Recovered', linestyle='dashed')
ax.plot(t, sidr_data[6], 'green', alpha=0.5, lw=2, label='Recovered')

ax.set_xlabel('Time /days')
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
ax.grid(visible=True, which='major', c='w', lw=2, ls='-')
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.savefig('SA_output1_3.png')
plt.show()
# Out:
# alpha: (goal 3.5e-4  0.00037330889608711004
# beta: (goal 0.3  0.30130329728126526
# gamma: (goal 0.18  0.1808522790670395
# sigma: (goal 0.05  0.04986406862735748
# lbda: (goal 0.06  0.060162998735904694
# rho: (goal 0.1  0.10069587826728821
# #################################

# %%
#calculate relative MSE loss
import math

S_total_loss = 0
S_den = 0
V_total_loss = 0
V_den = 0
E_total_loss = 0
E_den = 0
I_total_loss = 0
I_den = 0
D_total_loss = 0
D_den = 0
R_total_loss = 0
R_den = 0

for timestep in range(len(t)):
  S_value = sidr_data[1][timestep] - S[timestep]
  S_total_loss += S_value**2
  S_den += (sidr_data[1][timestep])**2

  V_value = sidr_data[2][timestep] - V[timestep]
  V_total_loss += V_value**2
  V_den += (sidr_data[2][timestep])**2

  E_value = sidr_data[3][timestep] - E[timestep]
  E_total_loss += E_value**2
  E_den += (sidr_data[3][timestep])**2

  I_value = sidr_data[4][timestep] - I[timestep]
  I_total_loss += I_value**2
  I_den += (sidr_data[4][timestep])**2

  D_value = sidr_data[5][timestep] - D[timestep]
  D_total_loss += D_value**2
  D_den += (sidr_data[5][timestep])**2

  R_value = sidr_data[6][timestep] - R[timestep]
  R_total_loss += R_value**2
  R_den += (sidr_data[6][timestep])**2

S_total_loss = math.sqrt(S_total_loss/S_den)
V_total_loss = math.sqrt(V_total_loss/V_den)
E_total_loss = math.sqrt(E_total_loss/E_den)
I_total_loss = math.sqrt(I_total_loss/I_den)
D_total_loss = math.sqrt(D_total_loss/D_den)
R_total_loss = math.sqrt(R_total_loss/R_den)

print('S_total_loss: ', S_total_loss)
print('V_total_loss: ', V_total_loss)
print('E_total_loss: ', E_total_loss)
print('I_total_loss: ', I_total_loss)
print('D_total_loss: ', D_total_loss)
print('R_total_loss: ', R_total_loss)
# Out:
# S_total_loss:  0.0
# V_total_loss:  0.0
# E_total_loss:  0.0
# I_total_loss:  0.0
# D_total_loss:  0.0
# R_total_loss:  0.0
